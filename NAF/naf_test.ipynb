# %%
from naf_core import*
# %matplotlib inline
# Out:
# [2016-07-16 20:46:51,540] Site environment registry incorrect: Scoreboard did not register all envs: set(['AcrobotContinuous-v0'])

# %%
car = NAF()
car.main()
# Out:
# [2016-07-16 20:46:51,739] Making new env: MountainCarContinuous-v0
# True action space: [ 0.], [ 2.]
# True state space: [-1.2  -0.07], [ 0.6   0.07]
# Filtered action space: [-1.], [ 1.]
# Filtered state space: [-1. -1.], [ 1.  1.]
# state dim 2
# action dim 1
# [2016-07-16 20:46:53,379] Action '[[ 0.72385566]]' is not contained within action space 'Box(1,)'.
# [2016-07-16 20:46:53,381] Observation '[[[ -5.91627236e-01]]
#
#  [[  2.32240210e-04]]]' is not contained within observation space 'Box(2,)'.
# result after minibatch no. 0 : mean squared error: 0.849964261055
# plotting the mu() policy learned by NN
# plotting the mu() policy learned by NN
# plotting the Qfunction
# Qfunction for action -1.0
# Qfunction for action -0.5
# Qfunction for action 0.0
# Qfunction for action 0.5
# Qfunction for action 1.0
# result after minibatch no. 1000 : mean squared error: 1.0011741324e-05
# plotting the mu() policy learned by NN
# plotting the mu() policy learned by NN
# ...
