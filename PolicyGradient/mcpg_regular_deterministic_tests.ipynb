# %%
import mountain_car_montecarlo_pg_linear as mcpg

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# # Testing with regular deterministic checks
#
#
# using linear features **without bias**

# %%
car1 = mcpg.mountain_car(alpha=1e-6)
# Out:
# [2016-05-08 17:46:23,465] Making new env: MountainCar-v0
# using policy mode: stochastic
# using alpha stepsize: 1e-06
# using epsilon schedule with N_0= 500.0

# %%
car1.train(iter=1000)
# Out:
# 1.0
# EPISODE #10
# with a exploration of 98.231827112%
# stochastic
# lasted 68098 steps
# theta
# [[ 0.00918155 -0.00412179 -0.00505976]
#  [-0.0540429   0.005651    0.04839189]]
# EPISODE #20
# with a exploration of 96.3391136802%
# stochastic
# lasted 27430 steps
# theta
# [[-0.00411953  0.00184021  0.00227932]
#  [-0.11677889  0.01171436  0.10506453]]
# EPISODE #30
# with a exploration of 94.5179584121%
# stochastic
# lasted 16663 steps
# theta
# [[-0.00352928 -0.00185692  0.0053862 ]
#  [-0.14951228  0.00662895  0.14288333]]
# EPISODE #40
# with a exploration of 92.7643784787%
# stochastic
# lasted 57006 steps
# theta
# [[-0.00884817 -0.00124959  0.01009775]
#  [-0.17410823  0.00479534  0.16931289]]
# EPISODE #50
# with a exploration of 91.0746812386%
# stochastic
# lasted 10737 steps
# theta
# [[-0.00982089  0.00794929  0.0018716 ]
#  [-0.19331799  0.00918381  0.18413417]]
# EPISODE #60
# with a exploration of 89.4454382826%
# stochastic
# lasted 32418 steps
# theta
# ...

# %%
checkgradient_car = mcpg.mountain_car(alpha=1e-6)
# Out:
# [2016-05-08 18:51:04,228] Making new env: MountainCar-v0
# using policy mode: stochastic
# using features of type:  2
# using alpha stepsize: 1e-06
# using epsilon schedule with N_0= 500.0

# %% [markdown]
# # Gradient comparison

# %%
checkgradient_car.compare_gradients()
# Out:
# average gradient computed with policy gradient theorem
# result after 200 episodes:
# [[ -4.47387876e+03   9.49755595e+03  -5.02367720e+03]
#  [  3.52579063e+02   4.96886908e+00  -3.57547933e+02]]
# average episode length before perturbation -732.09
# 0 0
# [[ -4.98570000e+09   0.00000000e+00   0.00000000e+00]
#  [  0.00000000e+00   0.00000000e+00   0.00000000e+00]]
# 0 1
# [[ -4.98570000e+09  -3.94170000e+09   0.00000000e+00]
#  [  0.00000000e+00   0.00000000e+00   0.00000000e+00]]
# 0 2
# [[ -4.98570000e+09  -3.94170000e+09   5.92760000e+09]
#  [  0.00000000e+00   0.00000000e+00   0.00000000e+00]]
# 1 0
# [[ -4.98570000e+09  -3.94170000e+09   5.92760000e+09]
#  [  3.81070000e+09   0.00000000e+00   0.00000000e+00]]
# 1 1
# [[ -4.98570000e+09  -3.94170000e+09   5.92760000e+09]
#  [  3.81070000e+09   9.18300000e+08   0.00000000e+00]]
# 1 2
# [[ -4.98570000e+09  -3.94170000e+09   5.92760000e+09]
#  [  3.81070000e+09   9.18300000e+08   2.00650000e+09]]
# ...

# %% [markdown]
# # Theta Dynamic Update

# %%
dynamic_car = mcpg.mountain_car(alpha=1e-6)
# Out:
# [2016-05-08 21:10:02,526] Making new env: MountainCar-v0
# using policy mode: stochastic
# using features of type:  2
# using alpha stepsize: 1e-06
# using epsilon schedule with N_0= 500.0

# %%
dynamic_car.train(iter=200)
# Out:
# 1.0
# ...
