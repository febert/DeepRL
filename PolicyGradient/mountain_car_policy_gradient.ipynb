# %%
import mountain_car_montecarlo_pg_linear as mcpg
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
reload(mcpg)
# Out:
# <module 'mountain_car_montecarlo_pg_linear' from 'mountain_car_montecarlo_pg_linear.pyc'>

# %%
testcar = mcpg.mountain_car()
# testcar.run_episode(self)
testcar.train(50)
# Out:
# [2016-05-03 16:14:50,898] Making new env: MountainCar-v0
# 0
# NEW EPISODE
# ('THETA update', 0)
# ('score ', array([[ -3.37372860e-01,  -3.31950063e-01,   6.69322924e-01],
#        [  1.37978029e-01,   1.35760225e-01,  -2.73738254e-01],
#        [ -5.34068944e-05,  -5.25484532e-05,   1.05955348e-04]]))
# ('value fcn ', -9945.0)
# ('theta', array([[ 0.00385111, -0.01019062, -0.00865677],
#        [-0.00388476,  0.00141312,  0.01455495],
#        [-0.02091926,  0.0060063 , -0.00269881]]))
# ('prob_distrib', array([ 0.33737286,  0.33195006,  0.33067708]))
# ('THETA update', 0)
# ('score ', array([[ -3.38681100e-01,  -3.33216298e-01,   6.71897398e-01],
#        [  1.38513070e-01,   1.36278087e-01,  -2.74791157e-01],
#        [ -5.36139917e-05,  -5.27489011e-05,   1.06362893e-04]]))
# ('value fcn ', -9945.0)
# ('theta', array([[  7.20627960e-03,  -6.88937908e-03,  -1.53131913e-02],
#        [ -5.25695287e-03,   6.29837916e-05,   1.72772745e-02],
# ...

# %%
fig = plt.figure()
plt.plot(testcar.episode_lengths)
fig = plt.figure()
plt.hist(testcar.episode_lengths)
plt.show()

# %%
testcar.run_episode(enable_render=True)

# %%
testcar.env.viewer.close()
