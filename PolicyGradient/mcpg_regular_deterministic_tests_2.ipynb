# %%
from pg_function_approx import *

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import numpy as np
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
car1 = mountain_car(init_alpha= 1e-3 , type_features = 4, constant_alpha= False)
# Out:
# [2016-05-17 14:32:18,358] Making new env: MountainCar-v0
# N_0 50.0
# init alpha 0.001
# Constant Alpha False

# %%
car1.train(iter=1000, dataname ='' , save = False)
# Out:
# 0 EPISODE #1.0
# with a exploration of 100.0%
# and learning rate of 0.001
# lasted 50704 steps
# ...

# %%
car1.init_alpha = 1e-4
car1.total_runs = 0.
car1.constant_alpha = False
car1.train(iter=1000, dataname ='' , save = False)
# Out:
# 0 EPISODE #1.0
# with a exploration of 90.9090909091%
# and learning rate of 0.0004472135955
# lasted 1000001 steps
# theta
# [  1.17193353  19.06268478  -1.47516425   0.45093767 -11.56116991
#   -5.54322345   6.29125125   0.93697245  10.38923638 -13.51946132
#   -4.816087    -1.38791012]
# plotting the eligibility traces
# plotting the value function
# 1 EPISODE #2.0
# with a exploration of 98.0392156863%
# and learning rate of 0.001
# lasted 176295 steps
# theta
# [  4.5857433   28.16022088  -3.67867609   0.57481496 -22.94382565
#  -10.82665322  11.93262714   2.10387061  18.35808234 -17.33356766
#   -8.25395105  -2.67868558]
# plotting the eligibility traces
# plotting the value function
# 2 EPISODE #3.0
# with a exploration of 96.1538461538%
# and learning rate of 0.000707106781187
# lasted 175361 steps
# theta
# [  6.35929349  33.0721758   -4.88598458   0.59800498 -29.15700478
#  -13.68732043  14.65318567   2.91234014  22.79771129 -19.38485537
#   -9.7672011   -3.51034512]
# ...

# %%
# %matplotlib
car1.plot_value_function()
# Out:
# Using matplotlib backend: Qt4Agg
# plotting the value function

# %%
car1.loaddata(dataname ='alpha_1e-3_feature4_schedule_50_100000iter')
episodelenghts_feature4 = car1.episode_lengths
testlenghts_feature4 = car1.test_lengths
# Out:
# [[-2.12793301  0.26071573  1.86721728]
#  [-3.34394784 -2.43359782  5.77754566]
#  [ 1.05304602  0.14679821 -1.19984423]
#  [-1.23776442 -0.94353312  2.18129755]]
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib
fig = plt.figure()
plt.plot(episodelenghts_feature4,label="quadratic features")
plt.yscale('log')

plt.legend( loc=1)


plt.xlabel("episodes")
plt.ylabel("Episode Length ")
plt.show()
# Out:
# Using matplotlib backend: Qt4Agg

# %%
fig = plt.figure()
plt.plot(testlenghts_feature4,label="deterministic policy")
plt.yscale('log')

plt.legend( loc=1)
plt.xlabel("episodes")
plt.ylabel("Episode Length ")
plt.show()

# %%
car1.plot_policy(mode ='deterministic')
