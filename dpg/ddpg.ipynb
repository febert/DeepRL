# %%
from ddpg2 import *
# %matplotlib inline
# Out:
# [2016-07-11 10:14:04,426] Site environment registry incorrect: Scoreboard did not register all envs: set(['AcrobotContinuous-v0'])

# %%
car = ddpg()
car.main()
# Out:
# [2016-07-11 10:14:04,461] Making new env: MountainCarContinuous-v0
# action limits (array([ 0.]), array([ 2.]))
# [2016-07-11 10:14:06,645] Action '[[ 1.1684821]]' is not contained within action space 'Box(1,)'.
# [2016-07-11 10:14:06,646] Observation '[[[ -5.45039812e-01]]
#
#  [[  3.31661235e-04]]]' is not contained within observation space 'Box(2,)'.
# starting episode no 0
# replay size 0
# starting episode no 1
# replay size 4780
# starting episode no 2
# replay size 9042
# starting episode no 3
# replay size 9623
# starting episode no 4
# replay size 10907
# starting episode no 5
# replay size 11860
# starting episode no 6
# replay size 13323
# starting episode no 7
# replay size 15953
# starting episode no 8
# replay size 18243
# starting episode no 9
# replay size 27322
# starting episode no 10
# replay size 29078
# starting episode no 11
# replay size 35058
# starting episode no 12
# replay size 35513
# starting episode no 13
# replay size 38068
# starting episode no 14
# ...
