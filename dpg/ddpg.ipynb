# %%
from ddpg2 import *
# %matplotlib inline
# Out:
# [2016-07-12 11:21:05,045] Site environment registry incorrect: Scoreboard did not register all envs: set(['AcrobotContinuous-v0'])

# %%
car = ddpg()
car.main()
# Out:
# [2016-07-12 11:21:05,072] Making new env: MountainCarContinuous-v0
# action limits (array([ 0.]), array([ 2.]))
# [2016-07-12 11:21:07,033] Action '1.0179361222' is not contained within action space 'Box(1,)'.
# starting episode no 0
# replay size 0
# starting episode no 1
# replay size 2787
# starting episode no 2
# replay size 4882
# starting episode no 3
# replay size 6681
# starting episode no 4
# replay size 9172
# starting episode no 5
# replay size 12312
# starting episode no 6
# replay size 12880
# starting episode no 7
# replay size 16530
# starting episode no 8
# replay size 26531
# starting episode no 9
# replay size 28719
# starting episode no 10
# replay size 29636
# starting episode no 11
# replay size 31763
# starting episode no 12
# replay size 34137
# starting episode no 13
# replay size 37703
# starting episode no 14
# replay size 38812
# starting episode no 15
# replay size 39772
# starting episode no 16
# replay size 41226
# starting episode no 17
# ...
