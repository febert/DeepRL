# %%
from ddpg2 import *
# %matplotlib inline
# Out:
# [2016-07-12 10:44:44,548] Site environment registry incorrect: Scoreboard did not register all envs: set(['AcrobotContinuous-v0'])

# %%
car = ddpg()
car.main()
# Out:
# [2016-07-12 10:44:44,583] Making new env: MountainCarContinuous-v0
# action limits (array([ 0.]), array([ 2.]))
# [2016-07-12 10:44:46,607] Action '[[ 1.47885922]]' is not contained within action space 'Box(1,)'.
# [2016-07-12 10:44:46,610] Observation '[[[-0.53380177]]
#
#  [[ 0.00055956]]]' is not contained within observation space 'Box(2,)'.
# starting episode no 0
# replay size 0
# stateprime [[[-0.53380177]]
#
#  [[ 0.00055956]]]
# stateprime [[[-0.53277548]]
#
#  [[ 0.00102629]]]
# stateprime [[[-0.53133665]]
#
#  [[ 0.00143883]]]
# stateprime [[[-0.52963871]]
#
#  [[ 0.00169794]]]
# stateprime [[[-0.52764376]]
#
#  [[ 0.00199495]]]
# stateprime [[[-0.52561308]]
#
#  [[ 0.00203068]]]
# stateprime [[[-0.52371257]]
#
#  [[ 0.00190051]]]
# stateprime [[[-0.52120644]]
#
#  [[ 0.00250612]]]
# stateprime [[[-0.51886697]]
#
#  [[ 0.00233947]]]
# stateprime [[[-0.51672717]]
#
#  [[ 0.0021398 ]]]
# stateprime [[[-0.51486081]]
#
#  [[ 0.00186636]]]
# stateprime [[[-0.51323271]]
#
# ...
