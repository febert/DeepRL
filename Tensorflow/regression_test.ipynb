# %%
from regression_test import *
# %pylab inline
# %load_ext autoreload
# %autoreload 2
# Out:
# [2016-06-14 09:55:50,030] Site environment registry incorrect: Scoreboard did not register all envs: set(['AcrobotContinuous-v0'])
# Populating the interactive namespace from numpy and matplotlib

# %%
t1 = regression_test()
t1.main()
t1.plot_target_function()
t1.plot_learned_function()
# Out:
# epoch 0, learning rate 0.001
# mean_squared_error at step 0: 0.0998656
# mean_squared_error at step 10: 0.0633855
# mean_squared_error at step 20: 0.0460456
# mean_squared_error at step 30: 0.0498644
# mean_squared_error at step 40: 0.0339587
# mean_squared_error at step 50: 0.0349246
# mean_squared_error at step 60: 0.0220144
# mean_squared_error at step 70: 0.0305223
# mean_squared_error at step 80: 0.0269879
# mean_squared_error at step 90: 0.0178603
# Adding run metadata for 99
# mean_squared_error at step 100: 0.0186828
# mean_squared_error at step 110: 0.0153505
# mean_squared_error at step 120: 0.0100999
# mean_squared_error at step 130: 0.0162504
# mean_squared_error at step 140: 0.010875
# mean_squared_error at step 150: 0.0102184
# mean_squared_error at step 160: 0.0171016
# mean_squared_error at step 170: 0.010107
# mean_squared_error at step 180: 0.0114611
# mean_squared_error at step 190: 0.00893435
# Adding run metadata for 199
# ...
