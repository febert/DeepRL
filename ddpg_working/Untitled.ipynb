# %%
from run import *
# %matplotlib inline
# Out:
# [2016-07-15 14:36:07,662] Site environment registry incorrect: Scoreboard did not register all envs: set(['AcrobotContinuous-v0'])

# %%
e = Experiment()
e.run()
# Out:
# [2016-07-15 14:36:07,868] Making new env: MountainCarContinuous-v0
# ('action center a_c', array([ 1.]))
# ('action scale a_c', array([ 1.]))
# True action space: [ 0.], [ 2.]
# True state space: [-1.2  -0.07], [ 0.6   0.07]
# Filtered action space: [-1.], [ 1.]
# Filtered state space: [-1. -1.], [ 1.  1.]
# observationspace action space ((2,), (1,))
# {'_entry_point': 'gym.envs.classic_control:MountainCarContinuousEnv',
#  '_env_name': 'MountainCarContinuous',
#  '_kwargs': {},
#  '_local_only': False,
#  'id': 'MountainCarContinuous-v0',
#  'nondeterministic': False,
#  'reward_threshold': -110.0,
#  'timestep_limit': 10000,
#  'trials': 100}
# [2016-07-15 14:36:10,495] Action '[ 1.04225063]' is not contained within action space 'Box(1,)'.
# [2016-07-15 14:36:10,496] Observation '[[ -4.83717122e-01]
#  [ -2.58070254e-04]]' is not contained within observation space 'Box(2,)'.
# 4513.0
# 2291.0
# 4992.0
# 1575.0
# 5336.0
# 6260.0
# 1495.0
# 5941.0
# 2188.0
# 1764.0
# ...
