# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# %%
from dqn_learning import *
# import cPickle

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# import numpy as np
# Out:
# [2016-08-19 01:30:47,745] Site environment registry incorrect: Scoreboard did not register all envs: set(['AcrobotContinuous-v0'])

# %%
car = q_learning(gamma=0.99, 
#                  lambda_=0.9, 
#                  init_epsilon = 0.0,
#                  update_epsilon = False,
                 init_epsilon = 1.0,
                 end_epsilon = 0.1,
                 update_epsilon = True,
                 exploration_decrease_length = 1e6,
#                  N_0= 50, 
                 environment = 'MountainCar-v0',
                 plot_resolution = 30,
                 nn_size_hidden = [400,300], # irrelevant parameter if from_pixels
                 nn_batch_size = 128,
                 nn_learning_rate = 2.5e-4,
                 replay_memory_size = 2e5,
                 descent_method = 'rmsprop',
#                  dropout_keep_prob = 0.5,
                 ema_decay_rate = 0.999,
                 train_frequency = 4.0,
                 from_pixels = True,
                 reg_weight = 0.0,
                 do_pretrain = False,
                 pretrain_steps = 0
                )
# Out:
# [2016-08-19 01:30:49,949] Making new env: MountainCar-v0
# conv 128 8 8 2
# weights std = 0.125
# [8, 8, 2, 32]
# bias std = 0.0
# conv 512 4 4 32
# weights std = 0.0625
# [4, 4, 32, 64]
# bias std = 0.0
# conv 576 3 3 64
# weights std = 0.0589255650989
# [3, 3, 64, 64]
# bias std = 0.0
# fc 7744
# weights std = 0.0160706086633
# bias std = 0.0
# fc 512
# weights std = 0.0441941738242
# bias std = 0.0
# Q-learning configured in nn graph
# descending with  rmsprop
# using environment MountainCar-v0
# qnn target q-learning False False

# %%
car.deepq_learning(num_iter = 100000, max_steps = 500000, max_learning_steps=50000)#, reset_replay_memory=True)
# Out:
# plot experiment. Watch out!
# plot test. May burn!!
# statesshape (900, 84, 84, 2)
# deepQshape (900, 3)
# plotting the evaluated deepQ-function for action 0
# /usr/lib/pymodules/python2.7/matplotlib/collections.py:548: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == 'face':
# plotting the evaluated deepQ-function for action 1
# plotting the evaluated deepQ-function for action 2
# plotting the evaluated deepQ-function star (optimal)
# Episode 1 total samples 17603 train steps 238
# Length 31842
# Episode 3 total samples 23666 train steps 427
# Length 9577
# exploration  0.977080600001
# plot experiment. Watch out!
# plot test. May burn!!
# statesshape (900, 84, 84, 2)
# deepQshape (900, 3)
# plotting the evaluated deepQ-function for action 0
# plotting the evaluated deepQ-function for action 1
# plotting the evaluated deepQ-function for action 2
# plotting the evaluated deepQ-function star (optimal)
# Episode 6 total samples 31238 train steps 664
# Length 11543
# Episode 8 total samples 36415 train steps 825
# Length 6575
# Episode 9 total samples 40885 train steps 965
# Length 8939
# Episode 11 total samples 48223 train steps 1194
# Length 11700
# Episode 12 total samples 54830 train steps 1401
# Length 13213
# exploration  0.950653000002
# plot experiment. Watch out!
# plot test. May burn!!
# statesshape (900, 84, 84, 2)
# deepQshape (900, 3)
# plotting the evaluated deepQ-function for action 0
# plotting the evaluated deepQ-function for action 1
# plotting the evaluated deepQ-function for action 2
# plotting the evaluated deepQ-function star (optimal)
# Episode 14 total samples 57524 train steps 1485
# Length 4595
# Episode 15 total samples 60770 train steps 1587
# Length 6492
# Episode 18 total samples 65798 train steps 1744
# Length 6394
# Episode 19 total samples 73975 train steps 1999
# Length 16353
# Episode 21 total samples 77969 train steps 2124
# Length 3171
# exploration  0.927848800002
# plot experiment. Watch out!
# plot test. May burn!!
# statesshape (900, 84, 84, 2)
# deepQshape (900, 3)
# plotting the evaluated deepQ-function for action 0
# plotting the evaluated deepQ-function for action 1
# plotting the evaluated deepQ-function for action 2
# plotting the evaluated deepQ-function star (optimal)
# Episode 23 total samples 83838 train steps 2307
# Length 7339
# Episode 25 total samples 89455 train steps 2483
# Length 8684
# Episode 28 total samples 97101 train steps 2722
# Length 11782
# Episode 30 total samples 100523 train steps 2829
# Length 4219
# Episode 32 total samples 105095 train steps 2972
# Length 5746
# Episode 33 total samples 111235 train steps 3164
# Length 12280
# exploration  0.899888500003
# plot experiment. Watch out!
# plot test. May burn!!
# statesshape (900, 84, 84, 2)
# deepQshape (900, 3)
# plotting the evaluated deepQ-function for action 0
# plotting the evaluated deepQ-function for action 1
# plotting the evaluated deepQ-function for action 2
# plotting the evaluated deepQ-function star (optimal)
# Episode 34 total samples 116662 train steps 3333
# Length 10853
# Episode 35 total samples 124210 train steps 3569
# Length 15095
# Episode 37 total samples 129566 train steps 3736
# Length 8597
# Episode 39 total samples 135271 train steps 3915
# Length 7845
# Episode 40 total samples 139712 train steps 4053
# Length 8882
# exploration  0.874259200004
# plot experiment. Watch out!
# plot test. May burn!!
# statesshape (900, 84, 84, 2)
# deepQshape (900, 3)
# plotting the evaluated deepQ-function for action 0
# plotting the evaluated deepQ-function for action 1
# plotting the evaluated deepQ-function for action 2
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-f449fc8a97f8> in <module>()
# ----> 1 car.deepq_learning(num_iter = 100000, max_steps = 500000, max_learning_steps=50000)#, reset_replay_memory=True)
#
# /home/ga24pug/DeepRL/q_learning_sarsa/dqn_learning.pyc in deepq_learning(self, num_iter, max_steps, max_learning_steps, learning_rate, reset_replay_memory)
#     330                         # print('last w', self.w)
#     331                         self.plot_deepQ_policy(mode='deterministic')
# --> 332                         self.plot_deepQ_function()
#     333
#     334                 is_first = False
#
# /home/ga24pug/DeepRL/q_learning_sarsa/dqn_learning.pyc in plot_deepQ_function(self)
#     431
#     432         # plotting Q*
# --> 433         print('plotting the evaluated deepQ-function star (optimal)')
#     434
#     435         # get values in a grid
#
# /home/ga24pug/mypython-deeprl/local/lib/python2.7/site-packages/ipykernel/iostream.pyc in write(self, string)
#     315
#     316             is_child = (not self._is_master_process())
# --> 317             self._buffer.write(string)
#     318             if is_child:
#     319                 # newlines imply flush in subprocesses
#
# ValueError: I/O operation on closed file

# %%
car.deepq_learning(num_iter = 100000, max_steps = 500000, max_learning_steps=50000)#, reset_replay_memory=True)
# Out:
# plot experiment. Watch out!
# plot test. May burn!!
# statesshape (900, 84, 84, 2)
# deepQshape (900, 3)
# plotting the evaluated deepQ-function for action 0
# plotting the evaluated deepQ-function for action 1
# plotting the evaluated deepQ-function for action 2
# plotting the evaluated deepQ-function star (optimal)
# Episode 2 total samples 142324 train steps 4135
# Length 1129
# Episode 4 total samples 145907 train steps 4247
# Length 2406
# Episode 5 total samples 152659 train steps 4458
# Length 13503
# Episode 6 total samples 158853 train steps 4652
# Length 12388
# Episode 7 total samples 164287 train steps 4821
# Length 10868
# exploration  0.851702500005
# plot experiment. Watch out!
# plot test. May burn!!
# statesshape (900, 84, 84, 2)
# deepQshape (900, 3)
# plotting the evaluated deepQ-function for action 0
# plotting the evaluated deepQ-function for action 1
# plotting the evaluated deepQ-function for action 2
# plotting the evaluated deepQ-function star (optimal)
# Episode 9 total samples 166928 train steps 4904
# Length 4305
# Episode 10 total samples 174567 train steps 5143
# Length 15278
# Episode 12 total samples 177399 train steps 5231
# Length 1308
# Episode 13 total samples 180055 train steps 5314
# Length 5311
# Episode 15 total samples 184738 train steps 5461
# Length 5466
# Episode 16 total samples 187287 train steps 5540
# Length 5098
# Episode 18 total samples 197039 train steps 5845
# Length 16090
# exploration  0.822664900006
# plot experiment. Watch out!
# plot test. May burn!!
# statesshape (900, 84, 84, 2)
# deepQshape (900, 3)
# plotting the evaluated deepQ-function for action 0
# plotting the evaluated deepQ-function for action 1
# plotting the evaluated deepQ-function for action 2
# plotting the evaluated deepQ-function star (optimal)
# Episode 19 total samples 199584 train steps 5924
# Length 5089
# Episode 20 total samples 204708 train steps 6085
# Length 10247
# Episode 21 total samples 209272 train steps 6227
# Length 9128
# Episode 22 total samples 212651 train steps 6333
# Length 6758
# Episode 23 total samples 215431 train steps 6420
# Length 5560
# Episode 24 total samples 218344 train steps 6511
# Length 5825
# Episode 25 total samples 224398 train steps 6700
# Length 12108
# exploration  0.798041800007
# plot experiment. Watch out!
# plot test. May burn!!
# statesshape (900, 84, 84, 2)
# deepQshape (900, 3)
# plotting the evaluated deepQ-function for action 0
# plotting the evaluated deepQ-function for action 1
# plotting the evaluated deepQ-function for action 2
# plotting the evaluated deepQ-function star (optimal)
# Episode 26 total samples 228068 train steps 6815
# Length 7340
# Episode 28 total samples 231690 train steps 6928
# Length 3047
# Episode 31 total samples 236496 train steps 7078
# Length 5442
# Episode 32 total samples 239113 train steps 7160
# Length 5233
# Episode 34 total samples 242501 train steps 7266
# Length 3125
# Episode 35 total samples 246509 train steps 7391
# Length 8016
# Episode 36 total samples 250396 train steps 7512
# Length 7774
# exploration  0.774643600007
# plot experiment. Watch out!
# plot test. May burn!!
# statesshape (900, 84, 84, 2)
# deepQshape (900, 3)
# plotting the evaluated deepQ-function for action 0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-f449fc8a97f8> in <module>()
# ----> 1 car.deepq_learning(num_iter = 100000, max_steps = 500000, max_learning_steps=50000)#, reset_replay_memory=True)
#
# /home/ga24pug/DeepRL/q_learning_sarsa/dqn_learning.pyc in deepq_learning(self, num_iter, max_steps, max_learning_steps, learning_rate, reset_replay_memory)
#     330                         # print('last w', self.w)
#     331                         self.plot_deepQ_policy(mode='deterministic')
# --> 332                         self.plot_deepQ_function()
#     333
#     334                 is_first = False
#
# /home/ga24pug/DeepRL/q_learning_sarsa/dqn_learning.pyc in plot_deepQ_function(self)
#     411
#     412         for action in range(self.num_actions):
# --> 413             print('plotting the evaluated deepQ-function for action {}'.format(action))
#     414
#     415             # get values in a grid
#
# /home/ga24pug/mypython-deeprl/local/lib/python2.7/site-packages/ipykernel/iostream.pyc in write(self, string)
#     315
#     316             is_child = (not self._is_master_process())
# --> 317             self._buffer.write(string)
#     318             if is_child:
#     319                 # newlines imply flush in subprocesses
#
# ValueError: I/O operation on closed file

# %%
car.deepq_learning(num_iter = 100000, max_steps = 500000)#, reset_replay_memory=True)
# Out:
# plot experiment. Watch out!
# plot test. May burn!!
# statesshape (900, 84, 84, 2)
# deepQshape (900, 3)
# plotting the evaluated deepQ-function for action 0
# plotting the evaluated deepQ-function for action 1
# plotting the evaluated deepQ-function for action 2
# plotting the evaluated deepQ-function star (optimal)
# Episode 0 total samples 282621 train steps 8519
# Length 10759
