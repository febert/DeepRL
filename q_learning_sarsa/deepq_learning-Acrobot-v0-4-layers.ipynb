# %%
from dqn_learning import *
# import cPickle

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# import numpy as np

# %%
car = q_learning(gamma=1., 
                 lambda_=0.9, 
#                  init_epsilon = 0.0,
#                  update_epsilon = False,
                 init_epsilon = 1.0,
                 end_epsilon = 0.1,
                 update_epsilon = True,
                 exploration_decrease_length = 1e6,
#                  N_0= 50, 
                 environment = 'Acrobot-v0',
                 plot_resolution = 30,
                 nn_size_hidden = [400,300,300,300], # [100,100] --> 0.01, [100,100,100] --> similar [400,300]
                 nn_batch_size = 32,
                 nn_learning_rate = 2.5e-3,
                 replay_memory_size = 1e6, # larger than nn_batch_size*1e3 or doesn't train
                 descent_method = 'grad',
#                  dropout_keep_prob = 0.5,
                 ema_decay_rate = 0.999                 
                )
# Out:
# [2016-07-07 01:34:30,436] Making new env: Acrobot-v0
# normaliztion mean [ 0.  0.  0.  0.]
# normalization var [   9.86960411    9.86960411  157.91366577  799.43792725]
# Q-learning configured in nn graph
# descending with  grad
# using environment Acrobot-v0
# qnn target q-learning False False

# %% [markdown]
# Didn't work once on 2.5e-3, not much better on 2.5e-2

# %%
car.deepq_learning(num_iter = 2000, max_steps = 5000, learning_rate=2.5e-2)#, reset_replay_memory=True)
# Out:
# Episode 4
# Length 738
# Episode 9
# Length 872
# Episode 14
# Length 3408
# Episode 19
# Length 3162
# Episode 24
# Length 746
# Episode 29
# Length 987
# Episode 34
# Length 4638
# Episode 39
# Length 3218
# Episode 44
# Length 1380
# Episode 49
# Length 2320
# Episode 54
# Length 1742
# Episode 59
# Length 406
# Episode 64
# Length 1147
# Episode 69
# Length 1391
# Episode 74
# Length 758
# Episode 79
# Length 401
# Episode 84
# Length 1274
# Episode 89
# Length 952
# Episode 94
# Length 519
# Episode 99
# Length 1057
# exploration  0.837199000005
# Episode 104
# Length 1059
# Episode 109
# Length 1614
# Episode 114
# Length 2352
# Episode 119
# Length 1240
# Episode 124
# Length 1675
# Episode 129
# Length 1221
# Episode 134
# Length 1144
# Episode 139
# Length 732
# Episode 144
# Length 1432
# Episode 149
# Length 1323
# Episode 154
# Length 1143
# Episode 159
# Length 835
# Episode 164
# Length 1124
# Episode 169
# Length 1086
# Episode 174
# Length 2127
# Episode 179
# ...

# %%
car.deepq_learning(num_iter = 2000, max_steps = 5000, learning_rate=2.5e-2)#, reset_replay_memory=True)
# Out:
# Episode 4
# Length 1206
# Episode 9
# Length 486
# Episode 14
# Length 612
# Episode 19
# Length 1119
# Episode 24
# Length 420
# Episode 29
# Length 1674
# Episode 34
# Length 638
# Episode 39
# Length 2634
# Episode 44
# Length 987
# Episode 49
# Length 434
# Episode 54
# Length 900
# Episode 59
# Length 1024
# Episode 64
# Length 506
# Episode 69
# Length 1011
# Episode 74
# Length 420
# Episode 79
# Length 662
# Episode 84
# Length 342
# Episode 89
# Length 1296
# Episode 94
# Length 302
# Episode 99
# Length 541
# exploration  0.0999991000096
# Episode 104
# Length 1430
# Episode 109
# Length 679
# Episode 114
# Length 391
# Episode 119
# Length 635
# Episode 124
# Length 1336
# Episode 129
# Length 425
# Episode 134
# Length 979
# Episode 139
# Length 940
# Episode 144
# Length 464
# Episode 149
# Length 768
# Episode 154
# Length 696
# Episode 159
# Length 352
# Episode 164
# Length 844
# Episode 169
# Length 654
# Episode 174
# Length 1651
# Episode 179
# Length 698
# ...
