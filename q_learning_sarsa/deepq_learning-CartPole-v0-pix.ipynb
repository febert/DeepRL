# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# %%
from dqn_learning import *
# import cPickle

# %load_ext autoreload
# %autoreload 2
# %pylab inline

# import numpy as np
# Out:
# [2016-08-19 12:53:21,059] Site environment registry incorrect: Scoreboard did not register all envs: set(['AcrobotContinuous-v0'])
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['copy']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
car = q_learning(gamma=0.99, 
#                  lambda_=0.9, 
#                  init_epsilon = 0.0,
#                  update_epsilon = False,
                 init_epsilon = 1.0,
                 end_epsilon = 0.1,
                 update_epsilon = True,
                 exploration_decrease_length = 1e6,
#                  N_0= 50, 
                 environment = 'CartPole-v0',
                 plot_resolution = 30,
                 nn_size_hidden = [400,300], # [100,100] --> 0.01, [100,100,100] --> similar [400,300]
                 nn_batch_size = 128,
                 nn_learning_rate = 2.5e-4,
                 replay_memory_size = 2e5, # larger than nn_batch_size*1e3 or doesn't train
                 descent_method = 'rmsprop',
                 dropout_keep_prob = 0.9,
                 ema_decay_rate = 0.999,
                 train_frequency = 4.0,
                 from_pixels = True,
                 reg_weight = 0.0,
                 do_pretrain = False,
                 pretrain_steps = 0
                )
# Out:
# [2016-08-19 12:53:23,158] Making new env: CartPole-v0
# conv 128 8 8 2
# weights std = 0.125
# [8, 8, 2, 32]
# bias std = 0.0
# conv 512 4 4 32
# weights std = 0.0625
# [4, 4, 32, 64]
# bias std = 0.0
# conv 576 3 3 64
# weights std = 0.0589255650989
# [3, 3, 64, 64]
# bias std = 0.0
# fc 7744
# weights std = 0.0160706086633
# bias std = 0.0
# fc 512
# weights std = 0.0441941738242
# bias std = 0.0
# Q-learning configured in nn graph
# descending with  rmsprop
# using environment CartPole-v0
# qnn target q-learning False False

# %%
car.deepq_learning(num_iter = 1000000, max_steps = 500000, max_learning_steps=1e6)#, reset_replay_memory=True)
# Out:
# Episode 1069 total samples 10026 train steps 1
# Length 31
# Episode 1318 total samples 12533 train steps 79
# Length 39
# Episode 1598 total samples 15036 train steps 157
# Length 12
# Episode 1857 total samples 17547 train steps 236
# Length 53
# Episode 2126 total samples 20048 train steps 314
# Length 22
# Episode 2381 total samples 22553 train steps 392
# Length 10
# exploration  0.977495500001
# /usr/lib/pymodules/python2.7/matplotlib/collections.py:548: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == 'face':
# Episode 2652 total samples 25056 train steps 470
# Length 16
# Episode 2892 total samples 27562 train steps 549
# Length 13
# Episode 3137 total samples 30073 train steps 627
# Length 30
# Episode 3398 total samples 32578 train steps 706
# Length 10
# Episode 3646 total samples 35079 train steps 784
# Length 16
# Episode 3906 total samples 37582 train steps 862
# ...

# %%
car.deepq_learning(num_iter = 1000000, max_steps = 500000, max_learning_steps=1e6)#, reset_replay_memory=True)

# %%
car.deepq_learning(num_iter = 100000, max_steps = 500000)#, reset_replay_memory=True)
