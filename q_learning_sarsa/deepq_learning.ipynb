# %%
from dqn_learning import *
import cPickle

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import numpy as np

# %%
car = q_learning(gamma=1., 
                 lambda_=0.9, 
                 init_epsilon = 0.0,
                 update_epsilon = False,
#                  init_epsilon = 1.0,
#                  end_epsilon = 0.1,
#                  update_epsilon = True,
#                  exploration_decrease_length = 1e5,
#                  N_0= 50, 
                 environment = 'MountainCar-v0',
                 tile_resolution = 16,
                 nn_size_hidden = [100,100,100], # [100,100] --> 0.01
                 nn_batch_size = 32,
                 nn_learning_rate = 2.5e-4,
                 replay_memory_size = 1e6,
                 descent_method = 'rmsprop'
                )
# Out:
# [2016-07-04 18:07:12,430] Making new env: MountainCar-v0
# lambda 0.9
# using environment MountainCar-v0
# tile resolution 16
# qnn target q-learning False False

# %%
car.deepq_learning(num_iter = 1000, max_steps = 5000)
# Out:
# Episode 0
# Episode 1
# Episode 2
# Episode 3
# Episode 4
# Episode 5
# Episode 6
# Length 3966
# Episode 7
# Length 3083
# Episode 8
# Length 1639
# Episode 9
# Length 234
# exploration  0.0
# statesshape (289, 2)
# deepQshape (289, 3)
# plotting the evaluated deepQ-function for action 0
# /usr/lib/pymodules/python2.7/matplotlib/collections.py:548: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == 'face':
# plotting the evaluated deepQ-function for action 1
# plotting the evaluated deepQ-function for action 2
# plotting the evaluated deepQ-function star (optimal)
# Episode 10
# Length 146
# Episode 11
# Length 150
# Episode 12
# Length 85
# Episode 13
# Length 85
# Episode 14
# Length 158
# Episode 15
# Length 159
# Episode 16
# Episode 17
# Length 1800
# Episode 18
# Length 477
# Episode 19
# Length 454
# exploration  0.0
# statesshape (289, 2)
# deepQshape (289, 3)
# ...
