# %%
from dqn_learning import *
# import cPickle

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# import numpy as np

# %%
car = q_learning(gamma=1., 
                 lambda_=0.9, 
#                  init_epsilon = 0.0,
#                  update_epsilon = False,
                 init_epsilon = 1.0,
                 end_epsilon = 0.1,
                 update_epsilon = True,
                 exploration_decrease_length = 1e6,
#                  N_0= 50, 
                 environment = 'MountainCar-v0',
                 plot_resolution = 30,
                 nn_size_hidden = [20,30], # [100,100] --> 0.01, [100,100,100] --> similar [400,300]
                 nn_batch_size = 32,
                 nn_learning_rate = 2.5e-4,
                 replay_memory_size = 1e6, # larger than nn_batch_size*1e3 or doesn't train
                 descent_method = 'rmsprop',
#                  dropout_keep_prob = 0.5,
                 ema_decay_rate = 0.999,
                 init_weights = 0.1
                )
# Out:
# [2016-07-12 13:53:12,415] Making new env: MountainCar-v0
# Calculating normalization by random action sampling...
# normaliztion mean [ -5.13837934e-01   5.69454496e-05]
# normalization var [ 0.12899569  0.00065095]
# init_weights 0.1
# weights std = 0.707106781187
# weights std = 0.22360679775
# weights std = 0.182574185835
# Q-learning configured in nn graph
# descending with  rmsprop
# using environment MountainCar-v0
# qnn target q-learning False False

# %%
car.deepq_learning(num_iter = 5000, max_steps = 2e5)#, reset_replay_memory=True)
# Out:
# statesshape (900, 2)
# deepQshape (900, 3)
# plotting the evaluated deepQ-function for action 0
# /usr/lib/pymodules/python2.7/matplotlib/collections.py:548: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == 'face':
# plotting the evaluated deepQ-function for action 1
# plotting the evaluated deepQ-function for action 2
# plotting the evaluated deepQ-function star (optimal)
# Episode 4 total samples 90620 train steps 1832
# Length 3240
# Episode 9 total samples 151679 train steps 3740
# Length 1116
# Episode 14 total samples 187737 train steps 4867
# Length 8671
# Episode 19 total samples 200959 train steps 5280
# Length 2977
# Episode 24 total samples 214229 train steps 5695
# Length 1916
# Episode 29 total samples 228496 train steps 6141
# Length 3345
# Episode 34 total samples 244157 train steps 6630
# Length 1979
# Episode 39 total samples 257113 train steps 7035
# Length 7623
# Episode 44 total samples 267207 train steps 7351
# Length 3439
# Episode 49 total samples 276201 train steps 7632
# Length 3927
# Episode 54 total samples 285019 train steps 7907
# Length 2805
# Episode 59 total samples 295191 train steps 8225
# Length 568
# Episode 64 total samples 302210 train steps 8445
# Length 1776
# Episode 69 total samples 313037 train steps 8783
# Length 2012
# Episode 74 total samples 320377 train steps 9012
# Length 1508
# Episode 79 total samples 324724 train steps 9148
# Length 529
# Episode 84 total samples 328112 train steps 9254
# Length 1087
# Episode 89 total samples 335338 train steps 9480
# Length 2205
# Episode 94 total samples 340763 train steps 9649
# Length 557
# Episode 99 total samples 347874 train steps 9872
# Length 618
# exploration  0.68691340001
# statesshape (900, 2)
# deepQshape (900, 3)
# plotting the evaluated deepQ-function for action 0
# plotting the evaluated deepQ-function for action 1
# plotting the evaluated deepQ-function for action 2
# plotting the evaluated deepQ-function star (optimal)
# Episode 104 total samples 354611 train steps 10082
# Length 1750
# Episode 109 total samples 357381 train steps 10169
# Length 430
# Episode 114 total samples 360910 train steps 10279
# Length 392
# Episode 119 total samples 365932 train steps 10436
# Length 421
# Episode 124 total samples 371231 train steps 10601
# Length 2164
# Episode 129 total samples 376557 train steps 10768
# Length 2420
# Episode 134 total samples 381170 train steps 10912
# Length 260
# Episode 139 total samples 384438 train steps 11014
# Length 498
# Episode 144 total samples 386432 train steps 11076
# Length 313
# Episode 149 total samples 390596 train steps 11207
# Length 623
# Episode 154 total samples 394742 train steps 11336
# Length 663
# Episode 159 total samples 400988 train steps 11531
# Length 422
# Episode 164 total samples 403460 train steps 11609
# Length 423
# Episode 169 total samples 406076 train steps 11690
# Length 477
# Episode 174 total samples 408511 train steps 11766
# Length 334
# Episode 179 total samples 411242 train steps 11852
# Length 659
# Episode 184 total samples 414605 train steps 11957
# Length 1535
# Episode 189 total samples 417367 train steps 12043
# Length 694
# Episode 194 total samples 420727 train steps 12148
# Length 529
# Episode 199 total samples 423800 train steps 12244
# Length 336
# exploration  0.618580000013
# statesshape (900, 2)
# deepQshape (900, 3)
# plotting the evaluated deepQ-function for action 0
# plotting the evaluated deepQ-function for action 1
# plotting the evaluated deepQ-function for action 2
# plotting the evaluated deepQ-function star (optimal)
# Episode 204 total samples 427272 train steps 12353
# Length 314
# Episode 209 total samples 429518 train steps 12423
# Length 614
# Episode 214 total samples 433587 train steps 12550
# Length 1334
# Episode 219 total samples 436497 train steps 12641
# Length 844
# Episode 224 total samples 439903 train steps 12747
# Length 350
# Episode 229 total samples 443337 train steps 12855
# Length 1250
# Episode 234 total samples 446479 train steps 12953
# Length 259
# Episode 239 total samples 449731 train steps 13055
# Length 374
# Episode 244 total samples 451957 train steps 13124
# Length 252
# Episode 249 total samples 454287 train steps 13197
# Length 396
# Episode 254 total samples 458372 train steps 13325
# Length 321
# Episode 259 total samples 460587 train steps 13394
# Length 419
# Episode 264 total samples 462953 train steps 13468
# Length 319
# Episode 269 total samples 465061 train steps 13534
# Length 263
# Episode 274 total samples 468283 train steps 13634
# Length 552
# Episode 279 total samples 472017 train steps 13751
# Length 820
# Episode 284 total samples 475284 train steps 13853
# Length 429
# Episode 289 total samples 478006 train steps 13938
# Length 1170
# Episode 294 total samples 481376 train steps 14043
# Length 611
# Episode 299 total samples 483914 train steps 14123
# Length 682
# exploration  0.564477400014
# statesshape (900, 2)
# deepQshape (900, 3)
# plotting the evaluated deepQ-function for action 0
# plotting the evaluated deepQ-function for action 1
# plotting the evaluated deepQ-function for action 2
# plotting the evaluated deepQ-function star (optimal)
# Episode 304 total samples 486815 train steps 14213
# Length 333
# Episode 309 total samples 489767 train steps 14306
# Length 499
# Episode 314 total samples 491430 train steps 14358
# Length 318
# Episode 319 total samples 493619 train steps 14426
# Length 243
# Episode 324 total samples 496682 train steps 14522
# Length 352
# Episode 329 total samples 499173 train steps 14600
# Length 566
# Episode 334 total samples 501762 train steps 14681
# Length 327
# Episode 339 total samples 503933 train steps 14748
# Length 404
# Episode 344 total samples 506505 train steps 14829
# Length 557
# Episode 349 total samples 507907 train steps 14873
# Length 244
# Episode 354 total samples 510504 train steps 14954
# Length 627
# Episode 359 total samples 512051 train steps 15002
# Length 260
# Episode 364 total samples 514202 train steps 15069
# Length 256
# Episode 369 total samples 516573 train steps 15143
# Length 713
# Episode 374 total samples 518427 train steps 15201
# Length 234
# Episode 379 total samples 520281 train steps 15259
# Length 411
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-dc24b0d3c9fb> in <module>()
# ----> 1 car.deepq_learning(num_iter = 5000, max_steps = 2e5)#, reset_replay_memory=True)
#
# /home/ga24pug/DeepRL/q_learning_sarsa/dqn_learning.pyc in deepq_learning(self, num_iter, max_steps, learning_rate, reset_replay_memory)
#     172
#     173                 state, reward, done, info = self.env.step(prev_action)
# --> 174                 action = self.policy(state, mode=self.policy_mode, deepQ=True)
#     175                 #                episode.append((state, action, reward))
#     176
#
# /home/ga24pug/DeepRL/q_learning_sarsa/dqn_learning.pyc in policy(self, state, mode, deepQ)
#     129         if mode == 'deterministic' and not explore:
#     130             if deepQ:
# --> 131                 q = self.qnn.evaluate_all_actions(np.array(state).reshape((1,-1)))
#     132                 # print(state, q)
#     133                 return np.argmax(q.squeeze())#np.random.choice(np.argwhere(q == np.amax(q)).flatten())
#
# /home/ga24pug/DeepRL/q_learning_sarsa/qnn.pyc in evaluate_all_actions(self, states)
#     484         # print(states, states.shape)
#     485         feed_dict = {self.s: states, self.keep_prob: 1.0, self.phase_train: False}
# --> 486         return self.sess.run(self.q_all, feed_dict=feed_dict)
#     487
#     488     # this does not seem to work
#
# /home/ga24pug/mypython-deeprl/local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     370     try:
#     371       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 372                          run_metadata_ptr)
#     373       if run_metadata:
#     374         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /home/ga24pug/mypython-deeprl/local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     634     try:
#     635       results = self._do_run(handle, target_list, unique_fetches,
# --> 636                              feed_dict_string, options, run_metadata)
#     637     finally:
#     638       # The movers are no longer used. Delete them.
#
# /home/ga24pug/mypython-deeprl/local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#     706     if handle is None:
#     707       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# --> 708                            target_list, options, run_metadata)
#     709     else:
#     710       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /home/ga24pug/mypython-deeprl/local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#     713   def _do_call(self, fn, *args):
#     714     try:
# --> 715       return fn(*args)
#     716     except errors.OpError as e:
#     717       message = compat.as_text(e.message)
#
# /home/ga24pug/mypython-deeprl/local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#     695         return tf_session.TF_Run(session, options,
#     696                                  feed_dict, fetch_list, target_list,
# --> 697                                  status, run_metadata)
#     698
#     699     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %% [markdown]
# ### FAN IN is off

# %%
from dqn_learning import *
# import cPickle

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# import numpy as np

# %%
car = q_learning(gamma=1., 
                 lambda_=0.9, 
#                  init_epsilon = 0.0,
#                  update_epsilon = False,
                 init_epsilon = 1.0,
                 end_epsilon = 0.1,
                 update_epsilon = True,
                 exploration_decrease_length = 1e6,
#                  N_0= 50, 
                 environment = 'MountainCar-v0',
                 plot_resolution = 30,
                 nn_size_hidden = [20,30], # [100,100] --> 0.01, [100,100,100] --> similar [400,300]
                 nn_batch_size = 32,
                 nn_learning_rate = 2.5e-4,
                 replay_memory_size = 1e6, # larger than nn_batch_size*1e3 or doesn't train
                 descent_method = 'rmsprop',
#                  dropout_keep_prob = 0.5,
                 ema_decay_rate = 0.999,
                 init_weights = 0.1
                )
# Out:
# [2016-07-12 14:01:58,900] Making new env: MountainCar-v0
# Calculating normalization by random action sampling...
# normaliztion mean [ -5.11346281e-01   4.54373949e-05]
# normalization var [ 0.1293783  0.0006494]
# init_weights 0.1
# weights std = 0.1
# weights std = 0.1
# weights std = 0.1
# Q-learning configured in nn graph
# descending with  rmsprop
# using environment MountainCar-v0
# qnn target q-learning False False

# %%
car.deepq_learning(num_iter = 5000, max_steps = 2e5)#, reset_replay_memory=True)
# Out:
# statesshape (900, 2)
# deepQshape (900, 3)
# plotting the evaluated deepQ-function for action 0
# /usr/lib/pymodules/python2.7/matplotlib/collections.py:548: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == 'face':
# plotting the evaluated deepQ-function for action 1
# plotting the evaluated deepQ-function for action 2
# plotting the evaluated deepQ-function star (optimal)
# Episode 4 total samples 285052 train steps 7908
# Length 39896
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-dc24b0d3c9fb> in <module>()
# ----> 1 car.deepq_learning(num_iter = 5000, max_steps = 2e5)#, reset_replay_memory=True)
#
# /home/ga24pug/DeepRL/q_learning_sarsa/dqn_learning.pyc in deepq_learning(self, num_iter, max_steps, learning_rate, reset_replay_memory)
#     172
#     173                 state, reward, done, info = self.env.step(prev_action)
# --> 174                 action = self.policy(state, mode=self.policy_mode, deepQ=True)
#     175                 #                episode.append((state, action, reward))
#     176
#
# /home/ga24pug/DeepRL/q_learning_sarsa/dqn_learning.pyc in policy(self, state, mode, deepQ)
#     129         if mode == 'deterministic' and not explore:
#     130             if deepQ:
# --> 131                 q = self.qnn.evaluate_all_actions(np.array(state).reshape((1,-1)))
#     132                 # print(state, q)
#     133                 return np.argmax(q.squeeze())#np.random.choice(np.argwhere(q == np.amax(q)).flatten())
#
# /home/ga24pug/DeepRL/q_learning_sarsa/qnn.py in evaluate_all_actions(self, states)
#     484         # print(states, states.shape)
#     485         feed_dict = {self.s: states, self.keep_prob: 1.0, self.phase_train: False}
# --> 486         return self.sess.run(self.q_all, feed_dict=feed_dict)
#     487
#     488     # this does not seem to work
#
# /home/ga24pug/mypython-deeprl/local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     370     try:
#     371       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 372                          run_metadata_ptr)
#     373       if run_metadata:
#     374         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /home/ga24pug/mypython-deeprl/local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     634     try:
#     635       results = self._do_run(handle, target_list, unique_fetches,
# --> 636                              feed_dict_string, options, run_metadata)
#     637     finally:
#     638       # The movers are no longer used. Delete them.
#
# /home/ga24pug/mypython-deeprl/local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#     706     if handle is None:
#     707       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# --> 708                            target_list, options, run_metadata)
#     709     else:
#     710       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /home/ga24pug/mypython-deeprl/local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#     713   def _do_call(self, fn, *args):
#     714     try:
# --> 715       return fn(*args)
#     716     except errors.OpError as e:
#     717       message = compat.as_text(e.message)
#
# /home/ga24pug/mypython-deeprl/local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#     695         return tf_session.TF_Run(session, options,
#     696                                  feed_dict, fetch_list, target_list,
# --> 697                                  status, run_metadata)
#     698
#     699     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
