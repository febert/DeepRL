# %% [markdown]
# ### With epochs. Decreasing length, increasing tries

# %%
from dqn_learning import *
# import cPickle

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# import numpy as np

# %%
car = q_learning(gamma=1., 
                 lambda_=0.9, 
#                  init_epsilon = 0.0,
#                  update_epsilon = False,
                 init_epsilon = 1.0,
                 end_epsilon = 0.1,
                 update_epsilon = True,
                 exploration_decrease_length = 1e6,
#                  N_0= 50, 
                 environment = 'MountainCar-v0',
                 plot_resolution = 30,
                 nn_size_hidden = [4,8,12,6], # [100,100] --> 0.01, [100,100,100] --> similar [400,300]
                 nn_batch_size = 32,
                 nn_learning_rate = 2.5e-4,
                 replay_memory_size = 1e6, # larger than nn_batch_size*1e3 or doesn't train
                 descent_method = 'rmsprop',
#                  dropout_keep_prob = 0.5,
                 ema_decay_rate = 0.999,
                 init_weights = 0.1
                )
# Out:
# [2016-07-11 19:01:43,443] Making new env: MountainCar-v0
# Calculating normalization by random action sampling...
# normaliztion mean [ -5.09656250e-01   3.82103171e-05]
# normalization var [ 0.13531925  0.0006725 ]
# init_weights 0.1
# Q-learning configured in nn graph
# descending with  rmsprop
# using environment MountainCar-v0
# qnn target q-learning False False

# %%
car.deepq_learning(num_iter = 1000, max_steps = 1000)#, reset_replay_memory=True)
# Out:
# statesshape (900, 2)
# deepQshape (900, 3)
# plotting the evaluated deepQ-function for action 0
# /usr/lib/pymodules/python2.7/matplotlib/collections.py:548: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == 'face':
# plotting the evaluated deepQ-function for action 1
# plotting the evaluated deepQ-function for action 2
# plotting the evaluated deepQ-function star (optimal)
# Episode 4
# Episode 9
# Episode 14
# Episode 19
# Episode 24
# Episode 29
# Episode 34
# Episode 39
# Episode 44
# Episode 49
# Episode 54
# Episode 59
# Episode 64
# Episode 69
# Episode 74
# Episode 79
# Episode 84
# Episode 89
# Episode 94
# Episode 99
# exploration  0.909910000003
# statesshape (900, 2)
# deepQshape (900, 3)
# plotting the evaluated deepQ-function for action 0
# plotting the evaluated deepQ-function for action 1
# plotting the evaluated deepQ-function for action 2
# plotting the evaluated deepQ-function star (optimal)
# Episode 104
# Episode 109
# Episode 114
# Episode 119
# Episode 124
# Episode 129
# Episode 134
# Episode 139
# Episode 144
# Episode 149
# Episode 154
# Episode 159
# Episode 164
# Episode 169
# Episode 174
# Episode 179
# Episode 184
# Episode 189
# Episode 194
# Episode 199
# exploration  0.820020700006
# statesshape (900, 2)
# deepQshape (900, 3)
# plotting the evaluated deepQ-function for action 0
# plotting the evaluated deepQ-function for action 1
# plotting the evaluated deepQ-function for action 2
# plotting the evaluated deepQ-function star (optimal)
# Episode 204
# Episode 209
# Episode 214
# Episode 219
# Episode 224
# Episode 229
# Episode 234
# Episode 239
# Episode 244
# Episode 249
# Episode 254
# Episode 259
# Episode 264
# Episode 269
# Episode 274
# Episode 279
# Episode 284
# Episode 289
# Episode 294
# Episode 299
# exploration  0.729930700009
# statesshape (900, 2)
# deepQshape (900, 3)
# plotting the evaluated deepQ-function for action 0
# plotting the evaluated deepQ-function for action 1
# plotting the evaluated deepQ-function for action 2
# plotting the evaluated deepQ-function star (optimal)
# Episode 304
# Episode 309
# Episode 314
# Episode 319
# Episode 324
# Episode 329
# Episode 334
# Episode 339
# Episode 344
# Episode 349
# Episode 354
# Episode 359
# Episode 364
# Episode 369
# Episode 374
# Episode 379
# Episode 384
# Episode 389
# Episode 394
# Episode 399
# exploration  0.639840700012
# statesshape (900, 2)
# deepQshape (900, 3)
# plotting the evaluated deepQ-function for action 0
# plotting the evaluated deepQ-function for action 1
# plotting the evaluated deepQ-function for action 2
# plotting the evaluated deepQ-function star (optimal)
# Episode 404
# Episode 409
# Episode 414
# Episode 419
# Episode 424
# Episode 429
# Episode 434
# Episode 439
# Episode 444
# Episode 449
# Episode 454
# Episode 459
# Episode 464
# Episode 469

# %%
car.deepq_learning(num_iter = 2000, max_steps = 500, reset_replay_memory=True)

# %%
car.deepq_learning(num_iter = 5000, max_steps = 200, reset_replay_memory=True)
