# %%
from dqn_learning import *
# import cPickle

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# import numpy as np

# %%
car = q_learning(gamma=1., 
                 lambda_=0.9, 
#                  init_epsilon = 0.0,
#                  update_epsilon = False,
                 init_epsilon = 1.0,
                 end_epsilon = 0.1,
                 update_epsilon = True,
                 exploration_decrease_length = 1e6,
#                  N_0= 50, 
                 environment = 'MountainCar-v0',
                 plot_resolution = 30,
                 nn_size_hidden = [20,30], # [100,100] --> 0.01, [100,100,100] --> similar [400,300]
                 nn_batch_size = 32,
                 nn_learning_rate = 2.5e-4,
                 replay_memory_size = 1e6, # larger than nn_batch_size*1e3 or doesn't train
                 descent_method = 'rmsprop',
#                  dropout_keep_prob = 0.5,
                 ema_decay_rate = 0.999,
                 init_weights = 0.1
                )
# Out:
# [2016-07-12 13:47:15,040] Making new env: MountainCar-v0
# Calculating normalization by random action sampling...
# normaliztion mean [ -5.13384998e-01   5.11849685e-05]
# normalization var [ 0.12635761  0.00063832]
# init_weights 0.1
# weights std = 1.41421356237
# weights std = 4.472135955
# weights std = 5.47722557505
# Q-learning configured in nn graph
# descending with  rmsprop
# using environment MountainCar-v0
# qnn target q-learning False False

# %%
car.deepq_learning(num_iter = 50000, max_steps = 2e5)#, reset_replay_memory=True)
# Out:
# statesshape (900, 2)
# deepQshape (900, 3)
# plotting the evaluated deepQ-function for action 0
# /usr/lib/pymodules/python2.7/matplotlib/collections.py:548: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == 'face':
# plotting the evaluated deepQ-function for action 1
# plotting the evaluated deepQ-function for action 2
# plotting the evaluated deepQ-function star (optimal)
# Episode 4 total samples 73698 train steps 1304
# Length 1824
# Episode 9 total samples 85991 train steps 1688
# Length 1095
# Episode 14 total samples 110395 train steps 2450
# Length 11625
# Episode 19 total samples 124584 train steps 2894
# Length 826
# Episode 24 total samples 141051 train steps 3408
# Length 1209
# Episode 29 total samples 153178 train steps 3787
# Length 2564
# Episode 34 total samples 160791 train steps 4025
# Length 1177
# Episode 39 total samples 167516 train steps 4235
# Length 1068
# Episode 44 total samples 174990 train steps 4469
# Length 1248
# Episode 49 total samples 180351 train steps 4636
# Length 878
# Episode 54 total samples 186137 train steps 4817
# Length 556
# Episode 59 total samples 193071 train steps 5034
# Length 1750
# Episode 64 total samples 198095 train steps 5191
# Length 908
# Episode 69 total samples 203328 train steps 5354
# Length 795
# Episode 74 total samples 208028 train steps 5501
# Length 771
# Episode 79 total samples 214445 train steps 5702
# Length 438
# Episode 84 total samples 218906 train steps 5841
# Length 758
# Episode 89 total samples 224820 train steps 6026
# Length 629
# Episode 94 total samples 228387 train steps 6138
# Length 645
# Episode 99 total samples 233715 train steps 6304
# Length 1138
# exploration  0.789656500007
# statesshape (900, 2)
# deepQshape (900, 3)
# plotting the evaluated deepQ-function for action 0
# plotting the evaluated deepQ-function for action 1
# plotting the evaluated deepQ-function for action 2
# plotting the evaluated deepQ-function star (optimal)
# Episode 104 total samples 238070 train steps 6440
# Length 611
# Episode 109 total samples 242954 train steps 6593
# Length 1343
# Episode 114 total samples 247882 train steps 6747
# Length 810
# Episode 119 total samples 251222 train steps 6851
# Length 519
# Episode 124 total samples 255018 train steps 6970
# Length 494
# Episode 129 total samples 259087 train steps 7097
# Length 763
# Episode 134 total samples 263168 train steps 7224
# Length 1030
# Episode 139 total samples 266239 train steps 7320
# Length 527
# Episode 144 total samples 269600 train steps 7425
# Length 496
# Episode 149 total samples 274017 train steps 7564
# Length 458
# Episode 154 total samples 278079 train steps 7690
# Length 653
# Episode 159 total samples 281374 train steps 7793
# Length 677
# Episode 164 total samples 285556 train steps 7924
# Length 1492
# Episode 169 total samples 288807 train steps 8026
# Length 325
# Episode 174 total samples 293692 train steps 8178
# Length 697
# Episode 179 total samples 297168 train steps 8287
# Length 1283
# Episode 184 total samples 301384 train steps 8419
# Length 253
# Episode 189 total samples 304911 train steps 8529
# Length 609
# Episode 194 total samples 307917 train steps 8623
# Length 375
# Episode 199 total samples 311592 train steps 8738
# Length 850
# exploration  0.719567200009
# statesshape (900, 2)
# deepQshape (900, 3)
# plotting the evaluated deepQ-function for action 0
# plotting the evaluated deepQ-function for action 1
# plotting the evaluated deepQ-function for action 2
# plotting the evaluated deepQ-function star (optimal)
# Episode 204 total samples 314503 train steps 8829
# Length 393
# Episode 209 total samples 317905 train steps 8935
# Length 818
# Episode 214 total samples 320614 train steps 9020
# Length 419
# Episode 219 total samples 324235 train steps 9133
# Length 456
# Episode 224 total samples 326793 train steps 9213
# Length 600
# Episode 229 total samples 329234 train steps 9289
# Length 689
# Episode 234 total samples 332844 train steps 9402
# Length 632
# Episode 239 total samples 335168 train steps 9474
# Length 361
# Episode 244 total samples 337478 train steps 9547
# Length 503
# Episode 249 total samples 341016 train steps 9657
# Length 470
# Episode 254 total samples 344099 train steps 9754
# Length 558
# Episode 259 total samples 347003 train steps 9844
# Length 412
# Episode 264 total samples 349562 train steps 9924
# Length 720
# Episode 269 total samples 352063 train steps 10002
# Length 453
# Episode 274 total samples 354451 train steps 10077
# Length 440
# Episode 279 total samples 357220 train steps 10164
# Length 537
# Episode 284 total samples 359285 train steps 10228
# Length 312
# Episode 289 total samples 362411 train steps 10326
# Length 429
# Episode 294 total samples 364562 train steps 10393
# Length 348
# Episode 299 total samples 366670 train steps 10459
# Length 346
# exploration  0.669997000011
# statesshape (900, 2)
# deepQshape (900, 3)
# plotting the evaluated deepQ-function for action 0
# plotting the evaluated deepQ-function for action 1
# plotting the evaluated deepQ-function for action 2
# plotting the evaluated deepQ-function star (optimal)
# Episode 304 total samples 369325 train steps 10542
# Length 834
# Episode 309 total samples 372230 train steps 10633
# Length 726
# Episode 314 total samples 374911 train steps 10716
# Length 564
# Episode 319 total samples 377188 train steps 10788
# Length 434
# Episode 324 total samples 379112 train steps 10848
# Length 363
# Episode 329 total samples 381439 train steps 10920
# Length 531
# Episode 334 total samples 383708 train steps 10991
# Length 565
# Episode 339 total samples 385768 train steps 11056
# Length 368
# Episode 344 total samples 388896 train steps 11153
# Length 627
# Episode 349 total samples 391223 train steps 11226
# Length 868
# Episode 354 total samples 394783 train steps 11337
# Length 457
# Episode 359 total samples 396856 train steps 11402
# Length 454
# Episode 364 total samples 399288 train steps 11478
# Length 446
# Episode 369 total samples 401957 train steps 11562
# Length 244
# Episode 374 total samples 404181 train steps 11631
# Length 338
# Episode 379 total samples 406289 train steps 11697
# Length 412
# Episode 384 total samples 408467 train steps 11765
# Length 485
# Episode 389 total samples 410670 train steps 11834
# Length 349
# Episode 394 total samples 412779 train steps 11900
# Length 742
# Episode 399 total samples 415118 train steps 11973
# Length 552
# exploration  0.626393800012
# statesshape (900, 2)
# deepQshape (900, 3)
# plotting the evaluated deepQ-function for action 0
# plotting the evaluated deepQ-function for action 1
# plotting the evaluated deepQ-function for action 2
# plotting the evaluated deepQ-function star (optimal)
# Episode 404 total samples 417054 train steps 12033
# Length 246
# Episode 409 total samples 419455 train steps 12108
# Length 595
# Episode 414 total samples 421873 train steps 12184
# Length 357
# Episode 419 total samples 423663 train steps 12240
# Length 331
# Episode 424 total samples 426282 train steps 12322
# Length 504
# Episode 429 total samples 428431 train steps 12389
# Length 494
# Episode 434 total samples 430758 train steps 12462
# Length 705
# Episode 439 total samples 432605 train steps 12519
# Length 259
# Episode 444 total samples 434300 train steps 12572
# Length 370
# Episode 449 total samples 437175 train steps 12662
# Length 648
# Episode 454 total samples 439649 train steps 12740
# Length 350
# Episode 459 total samples 441893 train steps 12810
# Length 641
# Episode 464 total samples 443929 train steps 12873
# Length 473
# Episode 469 total samples 445743 train steps 12930
# Length 374
# Episode 474 total samples 447731 train steps 12992
# Length 359
# Episode 479 total samples 449704 train steps 13054
# Length 730
# Episode 484 total samples 452115 train steps 13129
# Length 398
# Episode 489 total samples 454099 train steps 13191
# Length 344
# Episode 494 total samples 455922 train steps 13248
# Length 457
# Episode 499 total samples 457897 train steps 13310
# Length 408
# exploration  0.587892700014
# statesshape (900, 2)
# deepQshape (900, 3)
# plotting the evaluated deepQ-function for action 0
# plotting the evaluated deepQ-function for action 1
# plotting the evaluated deepQ-function for action 2
# plotting the evaluated deepQ-function star (optimal)
# Episode 504 total samples 459562 train steps 13362
# Length 404
# Episode 509 total samples 461507 train steps 13423
# Length 433
# Episode 514 total samples 463336 train steps 13480
# Length 441
# Episode 519 total samples 465511 train steps 13548
# Length 418
# Episode 524 total samples 467395 train steps 13607
# Length 415
# Episode 529 total samples 469567 train steps 13674
# Length 359
# Episode 534 total samples 471338 train steps 13730
# Length 341
# Episode 539 total samples 473535 train steps 13798
# Length 407
# Episode 544 total samples 475413 train steps 13857
# Length 562
# Episode 549 total samples 477520 train steps 13923
# Length 315
# Episode 554 total samples 480336 train steps 14011
# Length 946
# Episode 559 total samples 482170 train steps 14068
# Length 372
# Episode 564 total samples 483879 train steps 14122
# Length 286
# Episode 569 total samples 485580 train steps 14175
# Length 305
# Episode 574 total samples 488197 train steps 14257
# Length 1279
# Episode 579 total samples 490101 train steps 14316
# Length 261
# Episode 584 total samples 492615 train steps 14395
# Length 241
# Episode 589 total samples 494627 train steps 14458
# Length 608
# Episode 594 total samples 496732 train steps 14523
# Length 466
# Episode 599 total samples 498729 train steps 14586
# Length 433
# exploration  0.551143900015
# statesshape (900, 2)
# deepQshape (900, 3)
# plotting the evaluated deepQ-function for action 0
# plotting the evaluated deepQ-function for action 1
# plotting the evaluated deepQ-function for action 2
# plotting the evaluated deepQ-function star (optimal)
# Episode 604 total samples 500581 train steps 14644
# Length 287
# Episode 609 total samples 502160 train steps 14693
# Length 303
# Episode 614 total samples 504405 train steps 14763
# Length 615
# Episode 619 total samples 506171 train steps 14818
# Length 249
# Episode 624 total samples 507721 train steps 14867
# Length 356
# Episode 629 total samples 509694 train steps 14928
# Length 469
# Episode 634 total samples 511246 train steps 14977
# Length 274
# Episode 639 total samples 513085 train steps 15034
# Length 412
# Episode 644 total samples 514723 train steps 15086
# Length 384
# Episode 649 total samples 516569 train steps 15143
# Length 265
# Episode 654 total samples 518160 train steps 15193
# Length 318
# Episode 659 total samples 519785 train steps 15244
# Length 359
# Episode 664 total samples 521681 train steps 15303
# Length 375
# Episode 669 total samples 523632 train steps 15364
# Length 289
# Episode 674 total samples 525634 train steps 15427
# Length 623
# Episode 679 total samples 527180 train steps 15475
# Length 207
# Episode 684 total samples 528650 train steps 15521
# Length 272
# Episode 689 total samples 530740 train steps 15586
# Length 326
# Episode 694 total samples 532251 train steps 15633
# Length 397
# Episode 699 total samples 534146 train steps 15693
# Length 373
# exploration  0.519268600016
# statesshape (900, 2)
# deepQshape (900, 3)
# plotting the evaluated deepQ-function for action 0
# plotting the evaluated deepQ-function for action 1
# plotting the evaluated deepQ-function for action 2
# plotting the evaluated deepQ-function star (optimal)
# Episode 704 total samples 536173 train steps 15756
# Length 349
# Episode 709 total samples 537740 train steps 15805
# Length 353
# Episode 714 total samples 539576 train steps 15862
# Length 358
# Episode 719 total samples 541182 train steps 15912
# Length 289
# Episode 724 total samples 542612 train steps 15957
# Length 319
# Episode 729 total samples 544597 train steps 16019
# Length 575
# Episode 734 total samples 546144 train steps 16067
# Length 265
# Episode 739 total samples 548550 train steps 16143
# Length 360
# Episode 744 total samples 550205 train steps 16194
# Length 394
# Episode 749 total samples 551841 train steps 16246
# Length 193
# Episode 754 total samples 553782 train steps 16306
# Length 681
# Episode 759 total samples 556036 train steps 16377
# Length 754
# Episode 764 total samples 557887 train steps 16434
# Length 236
# Episode 769 total samples 559648 train steps 16489
# Length 313
# Episode 774 total samples 561099 train steps 16535
# Length 276
# Episode 779 total samples 563050 train steps 16596
# Length 285
# Episode 784 total samples 564752 train steps 16649
# Length 289
# Episode 789 total samples 566283 train steps 16697
# Length 280
# Episode 794 total samples 567770 train steps 16743
# Length 377
# Episode 799 total samples 569327 train steps 16792
# Length 368
# exploration  0.487605700016
# statesshape (900, 2)
# deepQshape (900, 3)
# plotting the evaluated deepQ-function for action 0
# plotting the evaluated deepQ-function for action 1
# plotting the evaluated deepQ-function for action 2
# plotting the evaluated deepQ-function star (optimal)
# Episode 804 total samples 570999 train steps 16844
# Length 198
# Episode 809 total samples 573135 train steps 16911
# Length 262
# Episode 814 total samples 574666 train steps 16959
# Length 211
# Episode 819 total samples 576259 train steps 17009
# Length 301
# Episode 824 total samples 577743 train steps 17055
# Length 257
# Episode 829 total samples 579169 train steps 17100
# Length 294
# Episode 834 total samples 580610 train steps 17145
# Length 267
# Episode 839 total samples 582172 train steps 17193
# Length 516
# Episode 844 total samples 583754 train steps 17243
# Length 275
# Episode 849 total samples 586075 train steps 17315
# Length 722
# Episode 854 total samples 587384 train steps 17356
# Length 200
# Episode 859 total samples 588702 train steps 17397
# Length 249
# Episode 864 total samples 590769 train steps 17462
# Length 408
# Episode 869 total samples 592500 train steps 17516
# Length 315
# Episode 874 total samples 593802 train steps 17557
# Length 209
# Episode 879 total samples 595834 train steps 17620
# Length 455
# Episode 884 total samples 597106 train steps 17660
# Length 318
# Episode 889 total samples 598953 train steps 17718
# Length 257
# Episode 894 total samples 600574 train steps 17768
# Length 208
# Episode 899 total samples 602211 train steps 17820
# Length 303
# exploration  0.458010100015
# statesshape (900, 2)
# deepQshape (900, 3)
# plotting the evaluated deepQ-function for action 0
# plotting the evaluated deepQ-function for action 1
# plotting the evaluated deepQ-function for action 2
# plotting the evaluated deepQ-function star (optimal)
# Episode 904 total samples 603970 train steps 17875
# Length 396
# Episode 909 total samples 605697 train steps 17929
# Length 485
# Episode 914 total samples 607167 train steps 17974
# Length 285
# Episode 919 total samples 608821 train steps 18026
# Length 286
# Episode 924 total samples 610381 train steps 18075
# Length 270
# Episode 929 total samples 612072 train steps 18128
# Length 245
# Episode 934 total samples 613842 train steps 18183
# Length 265
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-a6a765b8b9d6> in <module>()
# ----> 1 car.deepq_learning(num_iter = 50000, max_steps = 2e5)#, reset_replay_memory=True)
#
# /home/ga24pug/DeepRL/q_learning_sarsa/dqn_learning.pyc in deepq_learning(self, num_iter, max_steps, learning_rate, reset_replay_memory)
#     172
#     173                 state, reward, done, info = self.env.step(prev_action)
# --> 174                 action = self.policy(state, mode=self.policy_mode, deepQ=True)
#     175                 #                episode.append((state, action, reward))
#     176
#
# /home/ga24pug/DeepRL/q_learning_sarsa/dqn_learning.pyc in policy(self, state, mode, deepQ)
#     129         if mode == 'deterministic' and not explore:
#     130             if deepQ:
# --> 131                 q = self.qnn.evaluate_all_actions(np.array(state).reshape((1,-1)))
#     132                 # print(state, q)
#     133                 return np.argmax(q.squeeze())#np.random.choice(np.argwhere(q == np.amax(q)).flatten())
#
# /home/ga24pug/DeepRL/q_learning_sarsa/qnn.py in evaluate_all_actions(self, states)
#     484         # print(states, states.shape)
#     485         feed_dict = {self.s: states, self.keep_prob: 1.0, self.phase_train: False}
# --> 486         return self.sess.run(self.q_all, feed_dict=feed_dict)
#     487
#     488     # this does not seem to work
#
# /home/ga24pug/mypython-deeprl/local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     370     try:
#     371       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 372                          run_metadata_ptr)
#     373       if run_metadata:
#     374         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /home/ga24pug/mypython-deeprl/local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     634     try:
#     635       results = self._do_run(handle, target_list, unique_fetches,
# --> 636                              feed_dict_string, options, run_metadata)
#     637     finally:
#     638       # The movers are no longer used. Delete them.
#
# /home/ga24pug/mypython-deeprl/local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#     706     if handle is None:
#     707       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# --> 708                            target_list, options, run_metadata)
#     709     else:
#     710       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /home/ga24pug/mypython-deeprl/local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#     713   def _do_call(self, fn, *args):
#     714     try:
# --> 715       return fn(*args)
#     716     except errors.OpError as e:
#     717       message = compat.as_text(e.message)
#
# /home/ga24pug/mypython-deeprl/local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#     695         return tf_session.TF_Run(session, options,
#     696                                  feed_dict, fetch_list, target_list,
# --> 697                                  status, run_metadata)
#     698
#     699     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %% [markdown]
# ### Repeat

# %%
from dqn_learning import *
# import cPickle

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# import numpy as np

# %%
car = q_learning(gamma=1., 
                 lambda_=0.9, 
#                  init_epsilon = 0.0,
#                  update_epsilon = False,
                 init_epsilon = 1.0,
                 end_epsilon = 0.1,
                 update_epsilon = True,
                 exploration_decrease_length = 1e6,
#                  N_0= 50, 
                 environment = 'MountainCar-v0',
                 plot_resolution = 30,
                 nn_size_hidden = [20,30], # [100,100] --> 0.01, [100,100,100] --> similar [400,300]
                 nn_batch_size = 32,
                 nn_learning_rate = 2.5e-4,
                 replay_memory_size = 1e6, # larger than nn_batch_size*1e3 or doesn't train
                 descent_method = 'rmsprop',
#                  dropout_keep_prob = 0.5,
                 ema_decay_rate = 0.999,
                 init_weights = 0.1
                )
# Out:
# [2016-07-12 13:55:38,262] Making new env: MountainCar-v0
# Calculating normalization by random action sampling...
# normaliztion mean [ -5.13294816e-01   3.67903558e-05]
# normalization var [ 0.12090783  0.0006151 ]
# init_weights 0.1
# weights std = 0.707106781187
# weights std = 0.22360679775
# weights std = 0.182574185835
# Q-learning configured in nn graph
# descending with  rmsprop
# using environment MountainCar-v0
# qnn target q-learning False False

# %%
car.deepq_learning(num_iter = 50000, max_steps = 2e5)#, reset_replay_memory=True)
# Out:
# statesshape (900, 2)
# deepQshape (900, 3)
# plotting the evaluated deepQ-function for action 0
# /usr/lib/pymodules/python2.7/matplotlib/collections.py:548: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == 'face':
# plotting the evaluated deepQ-function for action 1
# plotting the evaluated deepQ-function for action 2
# plotting the evaluated deepQ-function star (optimal)
# Episode 4 total samples 75835 train steps 1370
# Length 6444
# Episode 9 total samples 106920 train steps 2342
# Length 7631
# Episode 14 total samples 132802 train steps 3151
# Length 4678
# Episode 19 total samples 148139 train steps 3630
# Length 2719
# Episode 24 total samples 157107 train steps 3910
# Length 815
# Episode 29 total samples 167209 train steps 4226
# Length 2231
# Episode 34 total samples 172396 train steps 4388
# Length 1317
# Episode 39 total samples 179126 train steps 4598
# Length 1227
# Episode 44 total samples 185749 train steps 4805
# Length 1553
# Episode 49 total samples 192141 train steps 5005
# Length 999
# Episode 54 total samples 200801 train steps 5276
# Length 1084
# Episode 59 total samples 204588 train steps 5394
# Length 731
# Episode 64 total samples 208323 train steps 5511
# Length 790
# Episode 69 total samples 212570 train steps 5643
# Length 1381
# Episode 74 total samples 216496 train steps 5766
# Length 570
# Episode 79 total samples 222444 train steps 5952
# Length 800
# Episode 84 total samples 227747 train steps 6118
# Length 1935
# Episode 89 total samples 233315 train steps 6292
# Length 1085
# Episode 94 total samples 238277 train steps 6447
# Length 740
# Episode 99 total samples 241294 train steps 6541
# Length 672
# exploration  0.782835400007
# statesshape (900, 2)
# deepQshape (900, 3)
# plotting the evaluated deepQ-function for action 0
# plotting the evaluated deepQ-function for action 1
# plotting the evaluated deepQ-function for action 2
# plotting the evaluated deepQ-function star (optimal)
# Episode 104 total samples 247556 train steps 6737
# Length 831
# Episode 109 total samples 252720 train steps 6898
# Length 392
# Episode 114 total samples 256996 train steps 7032
# Length 1144
# Episode 119 total samples 262037 train steps 7189
# Length 789
# Episode 124 total samples 266861 train steps 7340
# Length 1319
# Episode 129 total samples 270664 train steps 7459
# Length 704
# Episode 134 total samples 273850 train steps 7558
# Length 412
# Episode 139 total samples 277699 train steps 7679
# Length 501
# Episode 144 total samples 280483 train steps 7766
# Length 358
# Episode 149 total samples 283484 train steps 7859
# Length 600
# Episode 154 total samples 286545 train steps 7955
# Length 505
# Episode 159 total samples 289680 train steps 8053
# Length 637
# Episode 164 total samples 292016 train steps 8126
# Length 623
# Episode 169 total samples 295175 train steps 8225
# Length 457
# Episode 174 total samples 298499 train steps 8329
# Length 601
# Episode 179 total samples 303077 train steps 8472
# Length 585
# Episode 184 total samples 306405 train steps 8576
# Length 440
# Episode 189 total samples 309925 train steps 8686
# Length 497
# Episode 194 total samples 312514 train steps 8767
# Length 431
# Episode 199 total samples 316024 train steps 8876
# Length 537
# exploration  0.715578400009
# statesshape (900, 2)
# deepQshape (900, 3)
# plotting the evaluated deepQ-function for action 0
# plotting the evaluated deepQ-function for action 1
# plotting the evaluated deepQ-function for action 2
# plotting the evaluated deepQ-function star (optimal)
# Episode 204 total samples 319013 train steps 8970
# Length 517
# Episode 209 total samples 321610 train steps 9051
# Length 480
# Episode 214 total samples 324131 train steps 9130
# Length 437
# Episode 219 total samples 327244 train steps 9227
# Length 568
# Episode 224 total samples 329817 train steps 9307
# Length 266
# Episode 229 total samples 332120 train steps 9379
# Length 590
# Episode 234 total samples 334844 train steps 9464
# Length 1001
# Episode 239 total samples 337011 train steps 9532
# Length 366
# Episode 244 total samples 339336 train steps 9605
# Length 390
# Episode 249 total samples 342021 train steps 9689
# Length 643
# Episode 254 total samples 344306 train steps 9760
# Length 504
# Episode 259 total samples 347133 train steps 9848
# Length 1254
# Episode 264 total samples 349352 train steps 9918
# Length 478
# Episode 269 total samples 351198 train steps 9975
# Length 428
# Episode 274 total samples 353316 train steps 10042
# Length 539
# Episode 279 total samples 355832 train steps 10120
# Length 379
# Episode 284 total samples 358334 train steps 10198
# Length 404
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-a6a765b8b9d6> in <module>()
# ----> 1 car.deepq_learning(num_iter = 50000, max_steps = 2e5)#, reset_replay_memory=True)
#
# /home/ga24pug/DeepRL/q_learning_sarsa/dqn_learning.pyc in deepq_learning(self, num_iter, max_steps, learning_rate, reset_replay_memory)
#     172
#     173                 state, reward, done, info = self.env.step(prev_action)
# --> 174                 action = self.policy(state, mode=self.policy_mode, deepQ=True)
#     175                 #                episode.append((state, action, reward))
#     176
#
# /home/ga24pug/DeepRL/q_learning_sarsa/dqn_learning.pyc in policy(self, state, mode, deepQ)
#     124     def policy(self, state, mode='deterministic', deepQ=False):
#     125
# --> 126         explore = bool(np.random.choice([1, 0], p=[self.epsilon, 1 - self.epsilon]))
#     127
#     128         # print(explore, features, end="")
#
# KeyboardInterrupt:
