# %%
from dqn_learning import *
# import cPickle

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# import numpy as np

# %% [markdown]
# A learning rate of 1e-1 did not work

# %%
car = q_learning(gamma=1., 
                 lambda_=0.9, 
#                  init_epsilon = 0.0,
#                  update_epsilon = False,
                 init_epsilon = 1.0,
                 end_epsilon = 0.1,
                 update_epsilon = True,
                 exploration_decrease_length = 1e6,
#                  N_0= 50, 
                 environment = 'Acrobot-v0',
                 plot_resolution = 30,
                 nn_size_hidden = [400,300,300], # [100,100] --> 0.01, [100,100,100] --> similar [400,300]
                 nn_batch_size = 32,
                 nn_learning_rate = 2.5e-3,
                 replay_memory_size = 1e6, # larger than nn_batch_size*1e3 or doesn't train
                 descent_method = 'grad',
#                  dropout_keep_prob = 0.5,
                 ema_decay_rate = 0.999                 
                )
# Out:
# [2016-07-07 00:45:25,737] Making new env: Acrobot-v0
# normaliztion mean [ 0.  0.  0.  0.]
# normalization var [   9.86960411    9.86960411  157.91366577  799.43792725]
# Q-learning configured in nn graph
# descending with  grad
# using environment Acrobot-v0
# qnn target q-learning False False

# %%
car.deepq_learning(num_iter = 1000, max_steps = 5000, learning_rate=2.5e-3)#, reset_replay_memory=True)
# Out:
# Episode 4
# Length 1944
# Episode 9
# Length 1040
# Episode 14
# Length 1402
# Episode 19
# Length 934
# Episode 24
# Length 1801
# Episode 29
# Length 2444
# Episode 34
# Length 2820
# Episode 39
# Length 1284
# Episode 44
# Length 1435
# Episode 49
# Length 1512
# Episode 54
# Length 1267
# Episode 59
# Length 932
# Episode 64
# Length 970
# Episode 69
# Length 1360
# Episode 74
# Length 593
# Episode 79
# Length 781
# Episode 84
# Length 902
# Episode 89
# Length 1465
# Episode 94
# Length 1074
# Episode 99
# Length 2187
# exploration  0.851609800005
# Episode 104
# Length 2712
# Episode 109
# Length 1064
# Episode 114
# Length 1190
# Episode 119
# Length 1129
# Episode 124
# Length 383
# Episode 129
# Length 2761
# Episode 134
# Length 1764
# Episode 139
# Length 1985
# Episode 144
# Length 1308
# Episode 149
# Length 1345
# Episode 154
# Length 2114
# Episode 159
# Length 622
# Episode 164
# Length 1231
# Episode 169
# Length 448
# Episode 174
# Length 947
# Episode 179
# ...

# %%
car.deepq_learning(num_iter = 1000, max_steps = 5000, learning_rate=2.5e-3)#, reset_replay_memory=True)
# Out:
# Episode 4
# Length 373
# Episode 9
# Length 392
# Episode 14
# Length 898
# Episode 19
# Length 426
# Episode 24
# Length 499
# Episode 29
# Length 299
# Episode 34
# Length 509
# Episode 39
# Length 709
# Episode 44
# Length 535
# Episode 49
# Length 403
# Episode 54
# Length 761
# Episode 59
# Length 674
# Episode 64
# Length 384
# Episode 69
# Length 295
# Episode 74
# Length 419
# Episode 79
# Length 298
# Episode 84
# Length 502
# Episode 89
# Length 527
# Episode 94
# Length 410
# Episode 99
# Length 562
# exploration  0.185293000009
# Episode 104
# Length 350
# Episode 109
# Length 213
# Episode 114
# Length 404
# Episode 119
# Length 262
# Episode 124
# Length 345
# Episode 129
# Length 464
# Episode 134
# Length 407
# Episode 139
# Length 716
# Episode 144
# Length 370
# Episode 149
# Length 404
# Episode 154
# Length 301
# Episode 159
# Length 611
# Episode 164
# Length 301
# Episode 169
# Length 457
# Episode 174
# Length 218
# Episode 179
# Length 421
# Episode 184
# ...

# %% [markdown]
# Repetition to see if it holds:

# %%
car = q_learning(gamma=1., 
                 lambda_=0.9, 
#                  init_epsilon = 0.0,
#                  update_epsilon = False,
                 init_epsilon = 1.0,
                 end_epsilon = 0.1,
                 update_epsilon = True,
                 exploration_decrease_length = 1e6,
#                  N_0= 50, 
                 environment = 'Acrobot-v0',
                 plot_resolution = 30,
                 nn_size_hidden = [400,300,300], # [100,100] --> 0.01, [100,100,100] --> similar [400,300]
                 nn_batch_size = 32,
                 nn_learning_rate = 2.5e-3,
                 replay_memory_size = 1e6, # larger than nn_batch_size*1e3 or doesn't train
                 descent_method = 'grad',
#                  dropout_keep_prob = 0.5,
                 ema_decay_rate = 0.999                 
                )
# Out:
# [2016-07-07 01:21:21,189] Making new env: Acrobot-v0
# normaliztion mean [ 0.  0.  0.  0.]
# normalization var [   9.86960411    9.86960411  157.91366577  799.43792725]
# Q-learning configured in nn graph
# descending with  grad
# using environment Acrobot-v0
# qnn target q-learning False False

# %%
car.deepq_learning(num_iter = 2000, max_steps = 5000, learning_rate=2.5e-3)#, reset_replay_memory=True)
# Out:
# Episode 4
# Length 328
# Episode 9
# Length 1650
# Episode 14
# Episode 19
# Length 1589
# Episode 24
# Length 2314
# Episode 29
# Length 2230
# Episode 34
# Length 1354
# Episode 39
# Length 2045
# Episode 44
# Length 845
# Episode 49
# Length 862
# Episode 54
# Length 1025
# Episode 59
# Length 1806
# Episode 64
# Length 821
# Episode 69
# Length 942
# Episode 74
# Length 525
# Episode 79
# Length 1397
# Episode 84
# Length 597
# Episode 89
# Length 884
# Episode 94
# Length 651
# Episode 99
# Length 1200
# exploration  0.876462400004
# Episode 104
# Length 681
# Episode 109
# Length 650
# Episode 114
# Length 591
# Episode 119
# Length 881
# Episode 124
# Length 976
# Episode 129
# Length 2488
# Episode 134
# Length 681
# Episode 139
# Length 1757
# Episode 144
# Length 1112
# Episode 149
# Length 564
# Episode 154
# Length 1594
# Episode 159
# Length 1187
# Episode 164
# Length 1756
# Episode 169
# Length 620
# Episode 174
# Length 887
# Episode 179
# Length 699
# Episode 184
# ...

# %%
car.deepq_learning(num_iter = 500, max_steps = 5000, learning_rate=2.5e-3)#, reset_replay_memory=True)
# Out:
# Episode 4
# Length 1014
# Episode 9
# Length 664
# Episode 14
# Length 581
# Episode 19
# Length 2074
# Episode 24
# Length 640
# Episode 29
# Length 438
# Episode 34
# Length 916
# Episode 39
# Length 614
# Episode 44
# Length 950
# Episode 49
# Length 1939
# Episode 54
# Length 948
# Episode 59
# Length 835
# Episode 64
# Length 549
# Episode 69
# Length 804
# Episode 74
# Length 480
# Episode 79
# Length 1189
# Episode 84
# Length 923
# Episode 89
# Length 982
# Episode 94
# Length 672
# Episode 99
# Length 568
# exploration  0.0999991000096
# Episode 104
# Length 261
# Episode 109
# Length 919
# Episode 114
# Length 460
# Episode 119
# Length 410
# Episode 124
# Length 1708
# Episode 129
# Length 2127
# Episode 134
# Length 1407
# Episode 139
# Length 535
# Episode 144
# Length 194
# Episode 149
# Length 1079
# Episode 154
# Length 410
# Episode 159
# Length 2340
# Episode 164
# Length 411
# Episode 169
# Length 621
# Episode 174
# Length 1172
# Episode 179
# Length 271
# ...

# %%
car = q_learning(gamma=1., 
                 lambda_=0.9, 
#                  init_epsilon = 0.0,
#                  update_epsilon = False,
                 init_epsilon = 1.0,
                 end_epsilon = 0.1,
                 update_epsilon = True,
                 exploration_decrease_length = 1e6,
#                  N_0= 50, 
                 environment = 'Acrobot-v0',
                 plot_resolution = 30,
                 nn_size_hidden = [400,300,300], # [100,100] --> 0.01, [100,100,100] --> similar [400,300]
                 nn_batch_size = 32,
                 nn_learning_rate = 2.5e-3,
                 replay_memory_size = 1e6, # larger than nn_batch_size*1e3 or doesn't train
                 descent_method = 'grad',
#                  dropout_keep_prob = 0.5,
                 ema_decay_rate = 0.999                 
                )
# Out:
# [2016-07-07 02:41:47,574] Making new env: Acrobot-v0
# normaliztion mean [ 0.  0.  0.  0.]
# normalization var [   9.86960411    9.86960411  157.91366577  799.43792725]
# Q-learning configured in nn graph
# descending with  grad
# using environment Acrobot-v0
# qnn target q-learning False False

# %%
car.deepq_learning(num_iter = 2000, max_steps = 5000, learning_rate=2.5e-3)#, reset_replay_memory=True)
# Out:
# Episode 4
# Length 2949
# Episode 9
# Length 1154
# Episode 14
# Length 1292
# Episode 19
# Length 500
# Episode 24
# Length 1068
# Episode 29
# Length 614
# Episode 34
# Length 750
# Episode 39
# Length 1202
# Episode 44
# Length 874
# Episode 49
# Length 654
# Episode 54
# Length 770
# Episode 59
# Length 816
# Episode 64
# Length 808
# Episode 69
# Length 840
# Episode 74
# Length 1454
# Episode 79
# Length 1229
# Episode 84
# Length 4639
# Episode 89
# Length 1757
# Episode 94
# Length 1180
# Episode 99
# Length 2621
# exploration  0.857175400005
# Episode 104
# Length 2599
# Episode 109
# Length 1282
# Episode 114
# Length 2728
# Episode 119
# Length 1656
# Episode 124
# Length 1389
# Episode 129
# Length 2441
# Episode 134
# Length 895
# Episode 139
# Length 3005
# Episode 144
# Length 2349
# Episode 149
# Length 2318
# Episode 154
# Episode 159
# Length 1143
# Episode 164
# Length 1944
# Episode 169
# Length 1771
# Episode 174
# Length 1194
# Episode 179
# Length 794
# ...

# %%
car.deepq_learning(num_iter = 2000, max_steps = 5000, learning_rate=2.5e-3)#, reset_replay_memory=True)
# Out:
# Episode 4
# Length 696
# Episode 9
# Length 439
# Episode 14
# Length 388
# Episode 19
# Length 378
# Episode 24
# Length 343
# Episode 29
# Length 794
# Episode 34
# Length 460
# Episode 39
# Length 753
# Episode 44
# Length 521
# Episode 49
# Length 614
# Episode 54
# Length 251
# Episode 59
# Length 432
# Episode 64
# Length 1020
# Episode 69
# Length 735
# Episode 74
# Length 1339
# Episode 79
# Length 363
# Episode 84
# Length 407
# Episode 89
# Length 740
# Episode 94
# Length 419
# Episode 99
# Length 590
# exploration  0.0999991000096
# Episode 104
# Length 591
# Episode 109
# Length 357
# Episode 114
# Length 515
# Episode 119
# Length 383
# Episode 124
# Length 647
# Episode 129
# Length 675
# Episode 134
# Length 739
# Episode 139
# Length 441
# Episode 144
# Length 1042
# Episode 149
# Length 558
# Episode 154
# Length 687
# Episode 159
# Length 1334
# Episode 164
# Length 726
# Episode 169
# Length 713
# Episode 174
# Length 870
# Episode 179
# Length 1030
# Episode 184
# ...

# %%
car.deepq_learning(num_iter = 2000, max_steps = 5000, learning_rate=2.5e-3)#, reset_replay_memory=True)
# Out:
# Episode 4
# Length 693
# Episode 9
# Length 1565
# Episode 14
# Length 734
# Episode 19
# Length 670
# Episode 24
# Length 664
# Episode 29
# Length 595
# Episode 34
# Length 686
# Episode 39
# Length 597
# Episode 44
# Length 344
# Episode 49
# Length 569
# Episode 54
# Length 719
# Episode 59
# Length 385
# Episode 64
# Length 549
# Episode 69
# Length 609
# Episode 74
# Length 294
# Episode 79
# Length 434
# Episode 84
# Length 1229
# Episode 89
# Length 331
# Episode 94
# Length 424
# Episode 99
# Length 766
# exploration  0.0999991000096
# Episode 104
# Length 1214
# Episode 109
# Length 1076
# Episode 114
# Length 1610
# Episode 119
# Length 351
# Episode 124
# Length 663
# Episode 129
# Length 573
# Episode 134
# Length 539
# Episode 139
# Length 956
# Episode 144
# Length 489
# Episode 149
# Length 1027
# Episode 154
# Length 390
# Episode 159
# Length 326
# Episode 164
# Length 502
# Episode 169
# Length 484
# Episode 174
# Length 1077
# Episode 179
# Length 667
# ...

# %% [markdown]
# Now test without the ema decay, just use last state directly:
# Twice tested that it does not work.

# %%
car = q_learning(gamma=1., 
                 lambda_=0.9, 
#                  init_epsilon = 0.0,
#                  update_epsilon = False,
                 init_epsilon = 1.0,
                 end_epsilon = 0.1,
                 update_epsilon = True,
                 exploration_decrease_length = 1e6,
#                  N_0= 50, 
                 environment = 'Acrobot-v0',
                 plot_resolution = 30,
                 nn_size_hidden = [400,300,300], # [100,100] --> 0.01, [100,100,100] --> similar [400,300]
                 nn_batch_size = 32,
                 nn_learning_rate = 2.5e-3,
                 replay_memory_size = 1e6, # larger than nn_batch_size*1e3 or doesn't train
                 descent_method = 'grad',
#                  dropout_keep_prob = 0.5,
                 ema_decay_rate = 0.0                 
                )
# Out:
# [2016-07-07 02:08:54,918] Making new env: Acrobot-v0
# normaliztion mean [ 0.  0.  0.  0.]
# normalization var [   9.86960411    9.86960411  157.91366577  799.43792725]
# Q-learning configured in nn graph
# descending with  grad
# using environment Acrobot-v0
# qnn target q-learning False False

# %%
car.deepq_learning(num_iter = 2000, max_steps = 5000, learning_rate=2.5e-3)#, reset_replay_memory=True)
# Out:
# Episode 4
# Length 3265
# Episode 9
# Length 717
# Episode 14
# Length 1344
# Episode 19
# Length 2391
# Episode 24
# Length 1572
# Episode 29
# Length 1788
# Episode 34
# Length 1617
# Episode 39
# Episode 44
# Length 2084
# Episode 49
# Length 1470
# Episode 54
# Length 1312
# Episode 59
# Length 4156
# Episode 64
# Length 4537
# Episode 69
# Length 1117
# Episode 74
# Episode 79
# Episode 84
# Length 1337
# Episode 89
# Episode 94
# Episode 99
# Length 2072
# exploration  0.755302600008
# Episode 104
# Episode 109
# Episode 114
# Length 2908
# Episode 119
# Length 1884
# Episode 124
# Episode 129
# Length 4446
# Episode 134
# Length 3351
# Episode 139
# Length 918
# Episode 144
# Length 1868
# Episode 149
# Length 1601
# Episode 154
# Length 712
# Episode 159
# Length 1372
# Episode 164
# Episode 169
# Episode 174
# Length 740
# Episode 179
# Length 546
# Episode 184
# Length 3133
# Episode 189
# Length 4554
# Episode 194
# Length 1963
# Episode 199
# Length 2599
# ...
