# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# %%
from dqn_learning import *
# import cPickle

# %load_ext autoreload
# %autoreload 2
# %pylab inline

# import numpy as np
# Out:
# [2016-07-27 17:56:26,669] Site environment registry incorrect: Scoreboard did not register all envs: set(['AcrobotContinuous-v0'])
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['copy']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
car = q_learning(gamma=0.99, 
#                  lambda_=0.9, 
#                  init_epsilon = 0.0,
#                  update_epsilon = False,
                 init_epsilon = 1.0,
                 end_epsilon = 0.1,
                 update_epsilon = True,
                 exploration_decrease_length = 1e6,
#                  N_0= 50, 
                 environment = 'CartPole-v0',
                 plot_resolution = 30,
                 nn_size_hidden = [400,300], # [100,100] --> 0.01, [100,100,100] --> similar [400,300]
                 nn_batch_size = 128,
                 nn_learning_rate = 2.5e-4,
                 replay_memory_size = 1e6, # larger than nn_batch_size*1e3 or doesn't train
                 descent_method = 'rmsprop',
                 dropout_keep_prob = 0.9,
                 ema_decay_rate = 0.999,
                 train_frequency = 4.0
                )
# Out:
# [2016-07-27 17:56:28,353] Making new env: CartPole-v0
# Calculating normalization by random action sampling...
# normaliztion mean [ 0.00079329  0.00013061 -0.00013985  0.00086307]
# normalization var [ 0.00895897  0.32122675  0.01055979  0.73549575]
# fc 4
# weights std = 0.707106781187
# bias std = 0.0
# fc 400
# weights std = 0.0707106781187
# bias std = 0.0
# fc 300
# weights std = 0.057735026919
# bias std = 0.0
# Q-learning configured in nn graph
# descending with  rmsprop
# using environment CartPole-v0
# qnn target q-learning False False

# %%
car.deepq_learning(num_iter = 1000000, max_steps = 50000, max_learning_steps=1e6)#, reset_replay_memory=True)
# Out:
# Episode 1028 total samples 10019 train steps 1
# Length 19
# Episode 1280 total samples 12525 train steps 79
# Length 22
# Episode 1547 total samples 15029 train steps 157
# Length 10
# Episode 1812 total samples 17531 train steps 235
# Length 10
# Episode 2077 total samples 20033 train steps 314
# Length 15
# Episode 2334 total samples 22535 train steps 392
# Length 16
# exploration  0.977490100001
# /usr/lib/pymodules/python2.7/matplotlib/collections.py:548: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == 'face':
# Episode 2605 total samples 25040 train steps 470
# Length 15
# Episode 2849 total samples 27541 train steps 548
# Length 13
# Episode 3090 total samples 30042 train steps 626
# Length 11
# Episode 3359 total samples 32554 train steps 705
# Length 35
# Episode 3633 total samples 35059 train steps 783
# Length 22
# Episode 3902 total samples 37580 train steps 862
# Length 51
# Episode 4173 total samples 40088 train steps 940
# Length 16
# Episode 4427 total samples 42592 train steps 1018
# Length 23
# Episode 4683 total samples 45095 train steps 1097
# Length 15
# Episode 4946 total samples 47600 train steps 1175
# Length 22
# exploration  0.954986500001
# Episode 5204 total samples 50111 train steps 1253
# Length 22
# Episode 5457 total samples 52616 train steps 1332
# Length 16
# Episode 5727 total samples 55122 train steps 1410
# Length 23
# Episode 5987 total samples 57624 train steps 1488
# Length 10
# Episode 6251 total samples 60133 train steps 1567
# Length 20
# Episode 6523 total samples 62635 train steps 1645
# Length 38
# Episode 6799 total samples 65141 train steps 1723
# Length 17
# Episode 7059 total samples 67645 train steps 1801
# Length 10
# Episode 7314 total samples 70153 train steps 1880
# Length 16
# Episode 7548 total samples 72671 train steps 1958
# Length 44
# exploration  0.932482900002
# Episode 7788 total samples 75178 train steps 2037
# Length 21
# Episode 8023 total samples 77688 train steps 2115
# Length 21
# Episode 8260 total samples 80198 train steps 2194
# Length 48
# Episode 8492 total samples 82714 train steps 2272
# Length 31
# Episode 8737 total samples 85225 train steps 2351
# Length 25
# Episode 8975 total samples 87726 train steps 2429
# Length 9
# Episode 9198 total samples 90234 train steps 2507
# Length 35
# Episode 9430 total samples 92737 train steps 2586
# Length 21
# Episode 9658 total samples 95240 train steps 2664
# Length 38
# Episode 9880 total samples 97742 train steps 2742
# Length 23
# exploration  0.909972100003
# [2016-07-27 17:57:40,130] Observation '[-2.44521294 -2.21004674 -0.10183776 -0.10439945]' is not contained within observation space 'Box(4,)'.
# Episode 10123 total samples 100253 train steps 2820
# Length 47
# Episode 10358 total samples 102754 train steps 2899
# Length 14
# Episode 10577 total samples 105258 train steps 2977
# Length 12
# Episode 10807 total samples 107772 train steps 3055
# Length 29
# Episode 11036 total samples 110274 train steps 3134
# Length 10
# Episode 11260 total samples 112778 train steps 3212
# Length 9
# Episode 11485 total samples 115286 train steps 3290
# Length 19
# Episode 11705 total samples 117787 train steps 3368
# Length 19
# Episode 11940 total samples 120293 train steps 3447
# Length 22
# Episode 12161 total samples 122804 train steps 3525
# Length 27
# exploration  0.887464900004
# Episode 12396 total samples 125308 train steps 3603
# Length 49
# Episode 12609 total samples 127814 train steps 3682
# Length 53
# Episode 12820 total samples 130331 train steps 3760
# Length 74
# Episode 13046 total samples 132848 train steps 3839
# Length 34
# Episode 13266 total samples 135349 train steps 3917
# Length 17
# Episode 13497 total samples 137868 train steps 3996
# Length 39
# Episode 13705 total samples 140370 train steps 4074
# Length 10
# Episode 13921 total samples 142871 train steps 4152
# Length 18
# Episode 14124 total samples 145377 train steps 4231
# Length 36
# Episode 14354 total samples 147886 train steps 4309
# Length 29
# exploration  0.864964000004
# Episode 14578 total samples 150394 train steps 4387
# Length 37
# Episode 14782 total samples 152901 train steps 4466
# Length 13
# Episode 14983 total samples 155411 train steps 4544
# Length 19
# Episode 15204 total samples 157923 train steps 4623
# Length 28
# Episode 15418 total samples 160426 train steps 4701
# Length 66
# Episode 15634 total samples 162939 train steps 4779
# Length 34
# Episode 15834 total samples 165447 train steps 4858
# Length 32
# Episode 16049 total samples 167950 train steps 4936
# Length 42
# Episode 16254 total samples 170458 train steps 5014
# Length 31
# Episode 16473 total samples 172964 train steps 5093
# Length 15
# exploration  0.842457700005
# Episode 16682 total samples 175484 train steps 5171
# Length 61
# Episode 16900 total samples 177992 train steps 5250
# Length 17
# Episode 17107 total samples 180521 train steps 5329
# Length 82
# Episode 17298 total samples 183029 train steps 5407
# Length 40
# Episode 17510 total samples 185546 train steps 5486
# Length 33
# Episode 17736 total samples 188057 train steps 5564
# Length 46
# Episode 17932 total samples 190586 train steps 5643
# Length 83
# Episode 18135 total samples 193104 train steps 5722
# Length 36
# Episode 18339 total samples 195607 train steps 5800
# Length 8
# Episode 18556 total samples 198122 train steps 5879
# Length 33
# exploration  0.819955900006
# Episode 18766 total samples 200633 train steps 5957
# Length 30
# Episode 18964 total samples 203140 train steps 6036
# Length 20
# Episode 19169 total samples 205644 train steps 6114
# Length 11
# Episode 19374 total samples 208148 train steps 6192
# Length 11
# Episode 19591 total samples 210654 train steps 6270
# Length 13
# Episode 19789 total samples 213162 train steps 6349
# Length 16
# Episode 19982 total samples 215671 train steps 6427
# Length 41
# Episode 20182 total samples 218176 train steps 6505
# Length 13
# Episode 20381 total samples 220677 train steps 6584
# Length 58
# Episode 20590 total samples 223186 train steps 6662
# Length 25
# exploration  0.797446000007
# Episode 20802 total samples 225722 train steps 6741
# Length 86
# Episode 21009 total samples 228227 train steps 6820
# Length 38
# Episode 21197 total samples 230737 train steps 6898
# Length 107
# Episode 21395 total samples 233246 train steps 6976
# Length 19
# Episode 21584 total samples 235756 train steps 7055
# Length 30
# Episode 21787 total samples 238260 train steps 7133
# Length 15
# Episode 21995 total samples 240766 train steps 7211
# Length 17
# Episode 22180 total samples 243272 train steps 7290
# Length 88
# Episode 22384 total samples 245774 train steps 7368
# Length 18
# Episode 22586 total samples 248277 train steps 7446
# Length 40
# exploration  0.774943300007
# Episode 22761 total samples 250780 train steps 7524
# Length 17
# Episode 22951 total samples 253281 train steps 7603
# Length 112
# Episode 23151 total samples 255786 train steps 7681
# Length 14
# Episode 23361 total samples 258292 train steps 7759
# Length 12
# Episode 23552 total samples 260797 train steps 7837
# Length 26
# Episode 23754 total samples 263302 train steps 7916
# Length 16
# Episode 23965 total samples 265813 train steps 7994
# Length 39
# Episode 24154 total samples 268332 train steps 8073
# Length 54
# Episode 24360 total samples 270845 train steps 8151
# Length 29
# Episode 24546 total samples 273363 train steps 8230
# Length 44
# exploration  0.752442400008
# Episode 24727 total samples 275870 train steps 8308
# Length 17
# Episode 24933 total samples 278378 train steps 8387
# Length 25
# Episode 25126 total samples 280886 train steps 8465
# Length 20
# Episode 25315 total samples 283390 train steps 8543
# Length 34
# Episode 25490 total samples 285898 train steps 8622
# Length 39
# Episode 25682 total samples 288412 train steps 8700
# Length 70
# Episode 25876 total samples 290916 train steps 8779
# Length 10
# Episode 26077 total samples 293420 train steps 8857
# Length 15
# Episode 26272 total samples 295940 train steps 8936
# Length 39
# Episode 26454 total samples 298443 train steps 9014
# Length 16
# exploration  0.729926200009
# Episode 26626 total samples 300945 train steps 9092
# Length 14
# Episode 26816 total samples 303446 train steps 9170
# Length 13
# Episode 27003 total samples 305950 train steps 9248
# Length 11
# Episode 27200 total samples 308453 train steps 9327
# Length 14
# Episode 27395 total samples 310956 train steps 9405
# Length 19
# Episode 27580 total samples 313461 train steps 9483
# Length 9
# Episode 27753 total samples 315963 train steps 9561
# Length 45
# Episode 27920 total samples 318464 train steps 9639
# Length 10
# Episode 28102 total samples 320967 train steps 9718
# Length 37
# Episode 28285 total samples 323473 train steps 9796
# Length 37
# exploration  0.70740730001
# Episode 28478 total samples 325975 train steps 9874
# Length 32
# Episode 28657 total samples 328482 train steps 9953
# Length 39
# Episode 28829 total samples 330988 train steps 10031
# Length 19
# Episode 29012 total samples 333507 train steps 10110
# Length 47
# Episode 29198 total samples 336032 train steps 10188
# Length 55
# Episode 29357 total samples 338549 train steps 10267
# Length 41
# Episode 29529 total samples 341053 train steps 10345
# Length 14
# Episode 29712 total samples 343558 train steps 10424
# Length 11
# Episode 29899 total samples 346082 train steps 10503
# Length 56
# Episode 30087 total samples 348591 train steps 10581
# Length 18
# exploration  0.68490460001
# Episode 30259 total samples 351093 train steps 10659
# Length 30
# Episode 30437 total samples 353614 train steps 10738
# Length 90
# Episode 30611 total samples 356123 train steps 10816
# Length 29
# Episode 30789 total samples 358634 train steps 10895
# Length 33
# Episode 30966 total samples 361174 train steps 10974
# Length 96
# Episode 31145 total samples 363684 train steps 11053
# Length 24
# Episode 31321 total samples 366197 train steps 11131
# Length 83
# Episode 31489 total samples 368699 train steps 11209
# Length 23
# Episode 31670 total samples 371207 train steps 11288
# Length 15
# Episode 31854 total samples 373748 train steps 11367
# Length 97
# exploration  0.662398300011
# Episode 32045 total samples 376250 train steps 11445
# Length 15
# Episode 32199 total samples 378779 train steps 11524
# Length 109
# Episode 32364 total samples 381280 train steps 11602
# Length 19
# Episode 32541 total samples 383799 train steps 11681
# Length 100
# Episode 32713 total samples 386306 train steps 11760
# Length 68
# Episode 32870 total samples 388825 train steps 11838
# Length 41
# Episode 33040 total samples 391342 train steps 11917
# Length 70
# Episode 33215 total samples 393844 train steps 11995
# Length 23
# Episode 33387 total samples 396359 train steps 12074
# Length 38
# Episode 33539 total samples 398871 train steps 12152
# Length 52
# exploration  0.639880300012
# Episode 33698 total samples 401386 train steps 12231
# Length 49
# Episode 33868 total samples 403889 train steps 12309
# Length 11
# Episode 34049 total samples 406401 train steps 12388
# Length 35
# Episode 34203 total samples 408905 train steps 12466
# Length 17
# Episode 34383 total samples 411416 train steps 12544
# Length 79
# Episode 34537 total samples 413920 train steps 12622
# Length 16
# Episode 34701 total samples 416428 train steps 12701
# Length 50
# Episode 34870 total samples 418952 train steps 12780
# Length 51
# Episode 35038 total samples 421454 train steps 12858
# Length 42
# Episode 35205 total samples 423957 train steps 12936
# Length 30
# exploration  0.617376700013
# Episode 35378 total samples 426463 train steps 13014
# Length 14
# Episode 35532 total samples 428987 train steps 13093
# Length 74
# Episode 35692 total samples 431494 train steps 13172
# Length 13
# Episode 35864 total samples 434010 train steps 13250
# Length 68
# Episode 36031 total samples 436524 train steps 13329
# Length 56
# Episode 36196 total samples 439026 train steps 13407
# Length 10
# Episode 36375 total samples 441532 train steps 13485
# Length 31
# Episode 36542 total samples 444055 train steps 13564
# Length 79
# Episode 36714 total samples 446556 train steps 13642
# Length 24
# Episode 36878 total samples 449090 train steps 13722
# Length 88
# exploration  0.594867700013
# Episode 37043 total samples 451599 train steps 13800
# Length 22
# Episode 37216 total samples 454105 train steps 13878
# Length 16
# Episode 37362 total samples 456625 train steps 13957
# Length 68
# Episode 37511 total samples 459135 train steps 14035
# Length 46
# Episode 37668 total samples 461647 train steps 14114
# Length 67
# Episode 37823 total samples 464154 train steps 14192
# Length 25
# Episode 37970 total samples 466662 train steps 14271
# Length 15
# Episode 38154 total samples 469179 train steps 14349
# Length 34
# Episode 38318 total samples 471684 train steps 14428
# Length 20
# Episode 38481 total samples 474196 train steps 14506
# Length 30
# exploration  0.572345200014
# Episode 38650 total samples 476700 train steps 14584
# Length 10
# Episode 38805 total samples 479214 train steps 14663
# Length 73
# Episode 38965 total samples 481721 train steps 14741
# Length 38
# Episode 39112 total samples 484227 train steps 14820
# Length 124
# Episode 39285 total samples 486752 train steps 14898
# Length 58
# Episode 39451 total samples 489276 train steps 14977
# Length 58
# Episode 39600 total samples 491802 train steps 15056
# Length 69
# Episode 39772 total samples 494315 train steps 15135
# Length 42
# Episode 39918 total samples 496826 train steps 15213
# Length 27
# Episode 40079 total samples 499335 train steps 15292
# Length 46
# exploration  0.549844300015
# Episode 40237 total samples 501836 train steps 15370
# Length 30
# Episode 40405 total samples 504347 train steps 15448
# Length 25
# Episode 40559 total samples 506851 train steps 15527
# Length 18
# Episode 40715 total samples 509353 train steps 15605
# Length 19
# Episode 40881 total samples 511898 train steps 15684
# Length 164
# Episode 41036 total samples 514406 train steps 15763
# Length 18
# Episode 41196 total samples 516923 train steps 15841
# Length 37
# Episode 41335 total samples 519452 train steps 15920
# Length 58
# Episode 41476 total samples 521971 train steps 15999
# Length 37
# Episode 41617 total samples 524477 train steps 16077
# Length 224
# exploration  0.527342500016
# Episode 41764 total samples 526983 train steps 16156
# Length 19
# Episode 41905 total samples 529513 train steps 16235
# Length 71
# Episode 42052 total samples 532021 train steps 16313
# Length 57
# Episode 42194 total samples 534536 train steps 16392
# Length 29
# Episode 42353 total samples 537043 train steps 16470
# Length 17
# Episode 42512 total samples 539545 train steps 16548
# Length 61
# Episode 42666 total samples 542065 train steps 16627
# Length 40
# Episode 42829 total samples 544602 train steps 16706
# Length 98
# Episode 42966 total samples 547114 train steps 16785
# Length 43
# Episode 43103 total samples 549630 train steps 16863
# Length 38
# exploration  0.504838900016
# Episode 43251 total samples 552140 train steps 16942
# Length 19
# Episode 43380 total samples 554649 train steps 17020
# Length 62
# Episode 43533 total samples 557166 train steps 17099
# Length 79
# Episode 43676 total samples 559685 train steps 17178
# Length 67
# Episode 43810 total samples 562189 train steps 17256
# Length 50
# Episode 43960 total samples 564710 train steps 17335
# Length 64
# Episode 44107 total samples 567214 train steps 17413
# Length 11
# Episode 44258 total samples 569726 train steps 17491
# Length 37
# Episode 44374 total samples 572240 train steps 17570
# Length 35
# Episode 44515 total samples 574757 train steps 17649
# Length 105
# exploration  0.482333500016
# Episode 44649 total samples 577273 train steps 17727
# Length 40
# Episode 44794 total samples 579789 train steps 17806
# Length 47
# Episode 44926 total samples 582301 train steps 17884
# Length 42
# Episode 45048 total samples 584837 train steps 17964
# Length 82
# Episode 45176 total samples 587340 train steps 18042
# Length 30
# Episode 45327 total samples 589863 train steps 18121
# Length 94
# Episode 45449 total samples 592376 train steps 18199
# Length 37
# Episode 45578 total samples 594934 train steps 18279
# Length 140
# Episode 45711 total samples 597445 train steps 18358
# Length 37
# Episode 45826 total samples 599950 train steps 18436
# Length 66
# exploration  0.459829900015
# Episode 45967 total samples 602459 train steps 18514
# Length 58
# Episode 46090 total samples 604965 train steps 18593
# Length 48
# Episode 46205 total samples 607498 train steps 18672
# Length 87
# Episode 46338 total samples 610005 train steps 18750
# Length 59
# Episode 46454 total samples 612518 train steps 18829
# Length 37
# Episode 46570 total samples 615019 train steps 18907
# Length 49
# Episode 46686 total samples 617528 train steps 18985
# Length 28
# Episode 46798 total samples 620035 train steps 19064
# Length 30
# Episode 46914 total samples 622540 train steps 19142
# Length 23
# Episode 47037 total samples 625086 train steps 19221
# Length 96
# exploration  0.437329000015
# Episode 47142 total samples 627587 train steps 19300
# Length 53
# Episode 47248 total samples 630090 train steps 19378
# Length 9
# Episode 47355 total samples 632623 train steps 19457
# Length 87
# Episode 47461 total samples 635136 train steps 19535
# Length 64
# Episode 47566 total samples 637645 train steps 19614
# Length 22
# Episode 47670 total samples 640207 train steps 19694
# Length 211
# Episode 47791 total samples 642709 train steps 19772
# Length 12
# Episode 47900 total samples 645272 train steps 19852
# Length 137
# Episode 48012 total samples 647781 train steps 19931
# Length 37
# exploration  0.414822700014
# Episode 48113 total samples 650282 train steps 20009
# Length 18
# Episode 48210 total samples 652800 train steps 20087
# Length 143
# Episode 48320 total samples 655320 train steps 20166
# Length 40
# Episode 48415 total samples 657849 train steps 20245
# Length 104
# Episode 48518 total samples 660357 train steps 20324
# Length 76
# Episode 48612 total samples 662874 train steps 20402
# Length 94
# Episode 48693 total samples 665402 train steps 20481
# Length 75
# Episode 48781 total samples 667915 train steps 20560
# Length 169
# Episode 48886 total samples 670436 train steps 20639
# Length 76
# Episode 48988 total samples 672973 train steps 20718
# Length 89
# exploration  0.392320000013
# Episode 49076 total samples 675583 train steps 20799
# Length 220
# Episode 49155 total samples 678130 train steps 20879
# Length 260
# Episode 49247 total samples 680650 train steps 20958
# Length 52
# Episode 49340 total samples 683176 train steps 21037
# Length 57
# Episode 49432 total samples 685715 train steps 21116
# Length 195
# Episode 49527 total samples 688225 train steps 21195
# Length 36
# Episode 49616 total samples 690727 train steps 21273
# Length 58
# Episode 49716 total samples 693234 train steps 21351
# Length 85
# Episode 49804 total samples 695755 train steps 21430
# Length 181
# Episode 49903 total samples 698267 train steps 21508
# Length 25
# exploration  0.369727300013
# Episode 49992 total samples 700791 train steps 21587
# Length 73
# Episode 50074 total samples 703314 train steps 21666
# Length 95
# Episode 50153 total samples 705815 train steps 21744
# Length 60
# Episode 50228 total samples 708366 train steps 21824
# Length 145
# Episode 50312 total samples 710868 train steps 21902
# Length 58
# Episode 50389 total samples 713455 train steps 21983
# Length 230
# Episode 50473 total samples 715975 train steps 22062
# Length 44
# Episode 50558 total samples 718527 train steps 22141
# Length 144
# Episode 50644 total samples 721043 train steps 22220
# Length 109
# Episode 50721 total samples 723554 train steps 22299
# Length 163
# exploration  0.347221000012
# Episode 50781 total samples 726137 train steps 22379
# Length 291
# Episode 50847 total samples 728645 train steps 22458
# Length 137
# Episode 50910 total samples 731164 train steps 22536
# Length 39
# Episode 51001 total samples 733672 train steps 22615
# Length 35
# Episode 51070 total samples 736195 train steps 22694
# Length 60
# Episode 51145 total samples 738714 train steps 22772
# Length 98
# Episode 51229 total samples 741260 train steps 22852
# Length 177
# Episode 51287 total samples 743767 train steps 22930
# Length 90
# Episode 51364 total samples 746294 train steps 23009
# Length 66
# Episode 51428 total samples 748823 train steps 23088
# Length 66
# exploration  0.324698500011
# Episode 51497 total samples 751406 train steps 23169
# Length 174
# Episode 51556 total samples 753989 train steps 23250
# Length 185
# Episode 51623 total samples 756520 train steps 23329
# Length 73
# Episode 51695 total samples 759038 train steps 23407
# Length 79
# Episode 51767 total samples 761558 train steps 23486
# Length 66
# Episode 51824 total samples 764101 train steps 23566
# Length 172
# Episode 51890 total samples 766621 train steps 23644
# Length 125
# Episode 51954 total samples 769129 train steps 23723
# Length 94
# Episode 52008 total samples 771713 train steps 23804
# Length 188
# Episode 52070 total samples 774214 train steps 23882
# Length 86
# exploration  0.302193100011
# Episode 52127 total samples 776760 train steps 23961
# Length 242
# Episode 52183 total samples 779274 train steps 24040
# Length 94
# Episode 52246 total samples 781785 train steps 24118
# Length 112
# Episode 52302 total samples 784300 train steps 24197
# Length 125
# Episode 52350 total samples 786834 train steps 24276
# Length 315
# Episode 52404 total samples 789366 train steps 24355
# Length 117
# Episode 52464 total samples 792029 train steps 24438
# Length 568
# Episode 52517 total samples 794565 train steps 24518
# Length 174
# Episode 52563 total samples 797080 train steps 24596
# Length 117
# Episode 52610 total samples 799588 train steps 24675
# Length 210
# exploration  0.27968680001
# Episode 52660 total samples 802150 train steps 24755
# Length 133
# Episode 52713 total samples 804705 train steps 24835
# Length 136
# Episode 52777 total samples 807230 train steps 24913
# Length 64
# Episode 52824 total samples 809740 train steps 24992
# Length 131
# Episode 52878 total samples 812329 train steps 25073
# Length 238
# Episode 52927 total samples 814856 train steps 25152
# Length 72
# Episode 52974 total samples 817393 train steps 25231
# Length 81
# Episode 53023 total samples 819912 train steps 25310
# Length 96
# Episode 53084 total samples 822423 train steps 25388
# Length 55
# Episode 53132 total samples 825057 train steps 25471
# Length 280
# exploration  0.257158900009
# Episode 53177 total samples 827641 train steps 25551
# Length 179
# Episode 53227 total samples 830160 train steps 25630
# Length 37
# Episode 53256 total samples 832711 train steps 25710
# Length 187
# Episode 53291 total samples 835292 train steps 25790
# Length 554
# Episode 53330 total samples 837807 train steps 25869
# Length 591
# Episode 53377 total samples 840446 train steps 25951
# Length 465
# Episode 53413 total samples 842974 train steps 26030
# Length 331
# Episode 53451 total samples 845511 train steps 26110
# Length 344
# Episode 53479 total samples 848051 train steps 26189
# Length 215
# exploration  0.234627400009
# Episode 53531 total samples 850579 train steps 26268
# Length 104
# Episode 53573 total samples 853106 train steps 26347
# Length 168
# Episode 53611 total samples 855663 train steps 26427
# Length 125
# Episode 53648 total samples 858441 train steps 26514
# Length 792
# Episode 53689 total samples 860955 train steps 26592
# Length 146
# Episode 53721 total samples 863500 train steps 26672
# Length 137
# Episode 53764 total samples 866004 train steps 26750
# Length 73
# Episode 53803 total samples 868700 train steps 26834
# Length 800
# Episode 53832 total samples 871256 train steps 26914
# Length 306
# Episode 53867 total samples 873851 train steps 26995
# Length 232
# exploration  0.212094100009
# Episode 53912 total samples 876474 train steps 27077
# Length 360
# Episode 53947 total samples 879102 train steps 27159
# Length 483
# Episode 53971 total samples 881608 train steps 27238
# Length 98
# Episode 53993 total samples 884141 train steps 27317
# Length 162
# Episode 54029 total samples 886859 train steps 27402
# Length 476
# Episode 54061 total samples 889557 train steps 27486
# Length 639
# Episode 54093 total samples 892104 train steps 27566
# Length 376
# Episode 54121 total samples 894663 train steps 27646
# Length 492
# Episode 54160 total samples 897249 train steps 27727
# Length 360
# Episode 54192 total samples 899809 train steps 27807
# Length 305
# exploration  0.189350200009
# Episode 54222 total samples 902347 train steps 27886
# Length 102
# Episode 54248 total samples 904882 train steps 27965
# Length 478
# Episode 54271 total samples 907588 train steps 28050
# Length 432
# Episode 54298 total samples 910124 train steps 28129
# Length 489
# Episode 54319 total samples 912626 train steps 28207
# Length 27
# Episode 54342 total samples 915144 train steps 28286
# Length 159
# Episode 54361 total samples 917745 train steps 28367
# Length 421
# Episode 54384 total samples 920295 train steps 28447
# Length 148
# Episode 54404 total samples 922843 train steps 28526
# Length 643
# Episode 54424 total samples 925383 train steps 28606
# Length 200
# exploration  0.166807900009
