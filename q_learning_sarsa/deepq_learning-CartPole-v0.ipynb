# %%
from dqn_learning import *
# import cPickle

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# import numpy as np
# Out:
# [2016-07-19 12:24:20,729] Site environment registry incorrect: Scoreboard did not register all envs: set(['AcrobotContinuous-v0'])

# %%
car = q_learning(gamma=1., 
                 lambda_=0.9, 
                 init_epsilon = 0.0,
                 update_epsilon = False,
#                  init_epsilon = 1.0,
#                  end_epsilon = 0.1,
#                  update_epsilon = True,
                 exploration_decrease_length = 1e6,
#                  N_0= 50, 
                 environment = 'CartPole-v0',
                 plot_resolution = 30,
                 nn_size_hidden = [400,300], # [100,100] --> 0.01, [100,100,100] --> similar [400,300]
                 nn_batch_size = 32,
                 nn_learning_rate = 2.5e-4,
                 replay_memory_size = 1e6, # larger than nn_batch_size*1e3 or doesn't train
                 descent_method = 'rmsprop',
#                  dropout_keep_prob = 0.5,
                 ema_decay_rate = 0.999,
#                  train_frequency = 32.0
                )
# Out:
# [2016-07-19 12:24:23,603] Making new env: CartPole-v0
# Calculating normalization by random action sampling...
# normaliztion mean [ 0.00113114  0.00439976 -0.00111716 -0.0067388 ]
# normalization var [ 0.00907569  0.31679797  0.01057408  0.72801161]
# init_weights 0.1
# relu!!!!
# weights std = 0.707106781187
# relu!!!!
# weights std = 0.0707106781187
# weights std = 0.057735026919
# Q-learning configured in nn graph
# descending with  rmsprop
# using environment CartPole-v0
# qnn target q-learning False False

# %%
car.deepq_learning(num_iter = 1000000, max_steps = 5000, max_learning_steps=1e6)#, reset_replay_memory=True)
# Out:
# Episode 3406 total samples 32006 train steps 1
# Length 9
# Episode 4476 total samples 42012 train steps 313
# Length 9
# Episode 5545 total samples 52018 train steps 626
# Length 10
# Episode 6616 total samples 62022 train steps 939
# Length 9
# Episode 7690 total samples 72025 train steps 1251
# Length 11
# Episode 8722 total samples 82030 train steps 1564
# Length 9
# Episode 9637 total samples 92043 train steps 1877
# Length 13
# exploration  0.0
# Episode 10427 total samples 102049 train steps 2190
# Length 15
# Episode 11096 total samples 112055 train steps 2502
# Length 11
# Episode 11716 total samples 122064 train steps 2815
# Length 18
# [2016-07-19 12:28:21,176] Observation '[-2.42237449 -2.79630519  0.12144078  1.10639468]' is not contained within observation space 'Box(4,)'.
# Episode 12109 total samples 132066 train steps 3128
# Length 33
# Episode 12529 total samples 142075 train steps 3440
# Length 80
# Episode 12839 total samples 152118 train steps 3754
# Length 69
# Episode 13093 total samples 162132 train steps 4067
# Length 52
# Episode 13270 total samples 172137 train steps 4380
# Length 67
# Episode 13509 total samples 182158 train steps 4693
# Length 22
# Episode 13761 total samples 192186 train steps 5006
# Length 34
# exploration  0.0
# Episode 13928 total samples 202202 train steps 5319
# Length 33
# Episode 14163 total samples 212625 train steps 5645
# Length 1273
# Episode 14322 total samples 225260 train steps 6040
# Episode 14342 total samples 236878 train steps 6403
# Length 1751
# Episode 14466 total samples 246894 train steps 6716
# Length 59
# Episode 14622 total samples 256937 train steps 7030
# Length 55
# Episode 14736 total samples 266949 train steps 7343
# Length 63
# Episode 14843 total samples 280495 train steps 7766
# Length 3678
# Episode 14882 total samples 293057 train steps 8159
# exploration  0.0
# Episode 15001 total samples 303116 train steps 8473
# Length 81
# Episode 15105 total samples 313161 train steps 8787
# Length 84
# Episode 15178 total samples 323213 train steps 9101
# Length 112
# Episode 15261 total samples 335440 train steps 9483
# Episode 15330 total samples 345468 train steps 9796
# Length 67
# Episode 15452 total samples 360207 train steps 10257
# Episode 15492 total samples 372824 train steps 10651
# Episode 15551 total samples 384277 train steps 11009
# Episode 15592 total samples 396531 train steps 11392
# exploration  0.0
# Episode 15628 total samples 408373 train steps 11762
# Episode 15711 total samples 418399 train steps 12075
# Length 69
# Episode 15737 total samples 429990 train steps 12438
# Episode 15744 total samples 441883 train steps 12809
# Episode 15810 total samples 455528 train steps 13236
# Episode 15841 total samples 466969 train steps 13593
# Episode 15933 total samples 477022 train steps 13907
# Length 64
# Episode 16009 total samples 487247 train steps 14227
# Length 4848
# Episode 16071 total samples 497309 train steps 14541
# Length 121
# exploration  0.0
# Episode 16150 total samples 512019 train steps 15001
# Episode 16186 total samples 525676 train steps 15428
# Episode 16247 total samples 538888 train steps 15841
# Episode 16307 total samples 552042 train steps 16252
# Episode 16343 total samples 564492 train steps 16641
# Episode 16373 total samples 576768 train steps 17024
# Episode 16422 total samples 589648 train steps 17427
# Episode 16491 total samples 603148 train steps 17849
# exploration  0.0
# Episode 16561 total samples 617660 train steps 18302
# Episode 16582 total samples 629164 train steps 18662
# Episode 16658 total samples 643533 train steps 19111
# Episode 16758 total samples 653763 train steps 19431
# Episode 16805 total samples 666047 train steps 19814
# Episode 16863 total samples 679999 train steps 20250
# Episode 16898 total samples 691139 train steps 20599
# Length 3717
# Episode 16971 total samples 702502 train steps 20954
# Length 1713
# exploration  0.0
# Episode 17035 total samples 717024 train steps 21407
# Episode 17142 total samples 728271 train steps 21759
# Episode 17231 total samples 738334 train steps 22073
# Length 353
# Episode 17332 total samples 748360 train steps 22387
# Length 27
# Episode 17399 total samples 758910 train steps 22716
# Length 1233
# Episode 17463 total samples 771299 train steps 23104
# Episode 17530 total samples 785787 train steps 23556
# Episode 17558 total samples 798192 train steps 23944
# exploration  0.0
# Episode 17616 total samples 812104 train steps 24379
# Episode 17701 total samples 822162 train steps 24693
# Length 101
# Episode 17809 total samples 832212 train steps 25007
# Length 108
# Episode 17867 total samples 844292 train steps 25385
# Length 3776
# Episode 17945 total samples 854565 train steps 25706
# Episode 18028 total samples 864615 train steps 26020
# Length 64
# Episode 18056 total samples 876202 train steps 26382
# Episode 18084 total samples 888160 train steps 26755
# Episode 18171 total samples 903114 train steps 27223
# exploration  0.0
# Episode 18242 total samples 913249 train steps 27540
# Episode 18290 total samples 924272 train steps 27884
# Length 4150
# Episode 18322 total samples 935977 train steps 28250
# Episode 18347 total samples 947254 train steps 28602
# Episode 18377 total samples 958858 train steps 28965
# Episode 18440 total samples 973013 train steps 29407
# Episode 18524 total samples 983038 train steps 29720
# Length 67
# Episode 18550 total samples 994593 train steps 30082
# exploration  0.0
# Episode 18595 total samples 1004597 train steps 30394
# Length 36
# Episode 18669 total samples 1014705 train steps 30710
# Length 108
# Episode 18749 total samples 1024731 train steps 31023
# Length 30
# Episode 18900 total samples 1034804 train steps 31338
# Length 97
# Episode 19094 total samples 1044874 train steps 31653
# Length 103
# Episode 19189 total samples 1056949 train steps 32030
# Episode 19242 total samples 1067059 train steps 32346
# Length 1922
# Episode 19309 total samples 1079682 train steps 32741
# Length 3600
# Episode 19374 total samples 1092677 train steps 33147
# Episode 19398 total samples 1104271 train steps 33509
# exploration  0.0
# Episode 19551 total samples 1118894 train steps 33966
# Episode 19630 total samples 1132932 train steps 34405
# Episode 19699 total samples 1143458 train steps 34734
# Episode 19788 total samples 1155538 train steps 35111
# Episode 19824 total samples 1166958 train steps 35468
# Episode 19921 total samples 1176990 train steps 35781
# Length 50
# Episode 19930 total samples 1187678 train steps 36115
# Episode 19991 total samples 1201539 train steps 36549
# exploration  0.0
# Episode 20065 total samples 1211572 train steps 36862
# Length 137
# Episode 20147 total samples 1225763 train steps 37306
# Episode 20228 total samples 1235774 train steps 37618
# Length 36
# Episode 20327 total samples 1245829 train steps 37933
# Length 61
# Episode 20331 total samples 1255953 train steps 38249
# Episode 20375 total samples 1268414 train steps 38638
# Episode 20457 total samples 1278453 train steps 38952
# Length 90
# Episode 20518 total samples 1288469 train steps 39265
# Length 41
# Episode 20578 total samples 1299817 train steps 39620
# Length 2975
# exploration  0.0
# Episode 20656 total samples 1309826 train steps 39933
# Length 115
# Episode 20686 total samples 1321736 train steps 40305
# Episode 20700 total samples 1332580 train steps 40644
# Episode 20729 total samples 1344083 train steps 41003
# Episode 20766 total samples 1356126 train steps 41379
# Episode 20816 total samples 1369366 train steps 41793
# Episode 20834 total samples 1380443 train steps 42139
# Episode 20858 total samples 1391959 train steps 42499
# Episode 20913 total samples 1405049 train steps 42908
# exploration  0.0
# Episode 21009 total samples 1416030 train steps 43251
# Episode 21088 total samples 1426057 train steps 43565
# Length 33
# Episode 21172 total samples 1436088 train steps 43878
# Length 58
# Episode 21239 total samples 1446558 train steps 44205
# Length 1961
# Episode 21324 total samples 1460641 train steps 44646
# Episode 21333 total samples 1471106 train steps 44973
# Episode 21419 total samples 1481154 train steps 45287
# Length 70
# Episode 21490 total samples 1495835 train steps 45745
# Episode 21569 total samples 1507881 train steps 46122
# exploration  0.0
# Episode 21589 total samples 1519584 train steps 46487
# Episode 21626 total samples 1531205 train steps 46851
# Episode 21674 total samples 1543859 train steps 47246
# Episode 21684 total samples 1554355 train steps 47574
# Episode 21727 total samples 1567002 train steps 47969
# Episode 21790 total samples 1581290 train steps 48416
# Episode 21833 total samples 1593760 train steps 48805
# Episode 21888 total samples 1607319 train steps 49229
# exploration  0.0
# Episode 21953 total samples 1617341 train steps 49542
# Length 68
# Episode 22066 total samples 1627363 train steps 49856
# Length 31
# Episode 22138 total samples 1639509 train steps 50235
# Episode 22173 total samples 1650170 train steps 50568
# Episode 22265 total samples 1660247 train steps 50883
# Length 98
# Episode 22330 total samples 1670255 train steps 51196
# Length 78
# Episode 22426 total samples 1680262 train steps 51509
# Length 67
# Episode 22531 total samples 1690302 train steps 51822
# Length 49
# Episode 22636 total samples 1702924 train steps 52217
# exploration  0.0
# Episode 22778 total samples 1716283 train steps 52634
# Episode 22897 total samples 1726314 train steps 52948
# Length 59
# Episode 23037 total samples 1736428 train steps 53264
# Length 126
# Episode 23153 total samples 1748433 train steps 53639
# Episode 23205 total samples 1759496 train steps 53985
# Length 2574
# Episode 23225 total samples 1770663 train steps 54334
# Episode 23319 total samples 1780686 train steps 54647
# Length 86
# Episode 23351 total samples 1792703 train steps 55022
# Episode 23456 total samples 1804447 train steps 55389
# exploration  0.0
# Episode 23536 total samples 1814477 train steps 55703
# Length 78
# Episode 23580 total samples 1824669 train steps 56021
# Length 409
# Episode 23660 total samples 1839063 train steps 56471
# Episode 23832 total samples 1850836 train steps 56839
# Length 2037
# Episode 23927 total samples 1860854 train steps 57152
# Length 73
# Episode 23950 total samples 1872125 train steps 57504
# Episode 23974 total samples 1883651 train steps 57865
# Episode 24051 total samples 1893689 train steps 58178
# Length 51
# Episode 24095 total samples 1907664 train steps 58615
# exploration  0.0
# Episode 24178 total samples 1917738 train steps 58930
# Length 140
# Episode 24229 total samples 1928654 train steps 59271
# Length 2534
# Episode 24282 total samples 1938692 train steps 59585
# Length 89
# Episode 24318 total samples 1950631 train steps 59958
# Episode 24388 total samples 1960658 train steps 60271
# Length 49
# Episode 24466 total samples 1970768 train steps 60587
# Length 326
# Episode 24528 total samples 1984674 train steps 61022
# Episode 24559 total samples 1996596 train steps 61394
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-7c49863d6a8a> in <module>()
# ----> 1 car.deepq_learning(num_iter = 1000000, max_steps = 5000, max_learning_steps=1e6)#, reset_replay_memory=True)
#
# /home/ga24pug/DeepRL/q_learning_sarsa/dqn_learning.pyc in deepq_learning(self, num_iter, max_steps, max_learning_steps, learning_rate, reset_replay_memory)
#     186
#     187                 state, reward, done, info = self.env.step(prev_action)
# --> 188                 action = self.policy(state, mode=self.policy_mode, deepQ=True)
#     189                 #                episode.append((state, action, reward))
#     190
#
# /home/ga24pug/DeepRL/q_learning_sarsa/dqn_learning.pyc in policy(self, state, mode, deepQ)
#     136         if mode == 'deterministic' and not explore:
#     137             if deepQ:
# --> 138                 q = self.qnn.evaluate_all_actions(np.array(state).reshape((1,-1)))
#     139                 # print(state, q)
#     140                 return np.argmax(q.squeeze())#np.random.choice(np.argwhere(q == np.amax(q)).flatten())
#
# /home/ga24pug/DeepRL/q_learning_sarsa/qnn.pyc in evaluate_all_actions(self, states)
#     488         # print(states, states.shape)
#     489         feed_dict = {self.s: states, self.keep_prob: 1.0, self.phase_train: False}
# --> 490         return self.sess.run(self.q_all, feed_dict=feed_dict)
#     491
#     492     # this does not seem to work
#
# /home/ga24pug/mypython-deeprl/local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     370     try:
#     371       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 372                          run_metadata_ptr)
#     373       if run_metadata:
#     374         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /home/ga24pug/mypython-deeprl/local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     582
#     583     # Validate and process fetches.
# --> 584     processed_fetches = self._process_fetches(fetches)
#     585     unique_fetches = processed_fetches[0]
#     586     target_list = processed_fetches[1]
#
# /home/ga24pug/mypython-deeprl/local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _process_fetches(self, fetches)
#     522       for subfetch in subfetches:
#     523         try:
# --> 524           fetch_t = self.graph.as_graph_element(subfetch, allow_tensor=True,
#     525                                                 allow_operation=True)
#     526           fetch_name = compat.as_bytes(fetch_t.name)
#
# /home/ga24pug/mypython-deeprl/local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in graph(self)
#     178   def graph(self):
#     179     """The graph that was launched in this session."""
# --> 180     return self._graph
#     181
#     182   @property
#
# KeyboardInterrupt:

# %%
from dqn_learning import *
# import cPickle

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# import numpy as np
# Out:
# [2016-07-19 16:58:51,037] Site environment registry incorrect: Scoreboard did not register all envs: set(['AcrobotContinuous-v0'])

# %%
car = q_learning(gamma=0.99, 
#                  lambda_=0.9, 
#                  init_epsilon = 0.0,
#                  update_epsilon = False,
                 init_epsilon = 1.0,
                 end_epsilon = 0.1,
                 update_epsilon = True,
                 exploration_decrease_length = 1e6,
#                  N_0= 50, 
                 environment = 'CartPole-v0',
                 plot_resolution = 30,
                 nn_size_hidden = [400,400,300], # [100,100] --> 0.01, [100,100,100] --> similar [400,300]
                 nn_batch_size = 1024,
                 nn_learning_rate = 2.5e-2,
                 replay_memory_size = 1e6, # larger than nn_batch_size*1e3 or doesn't train
                 descent_method = 'rmsprop',
#                  dropout_keep_prob = 0.5,
                 ema_decay_rate = 0.999,
                 train_frequency = 8.0
                )
# Out:
# [2016-07-19 16:58:54,635] Making new env: CartPole-v0
# Calculating normalization by random action sampling...
# normaliztion mean [-0.0005152   0.00272016  0.00033772 -0.00207438]
# normalization var [ 0.00981077  0.32447088  0.01071275  0.72724485]
# relu!!!!
# weights std = 0.707106781187
# bias std = 0.0
# relu!!!!
# weights std = 0.0707106781187
# bias std = 0.0
# relu!!!!
# weights std = 0.0707106781187
# bias std = 0.0
# weights std = 0.057735026919
# bias std = 0.0
# Q-learning configured in nn graph
# descending with  rmsprop
# using environment CartPole-v0
# qnn target q-learning False False

# %%
car.deepq_learning(num_iter = 1000000, max_steps = 50000, max_learning_steps=1e6)#, reset_replay_memory=True)
# Out:
# Episode 2281 total samples 50070 train steps 1
# Length 22
# exploration  0.954937000001
# Episode 2344 total samples 51333 train steps 11
# Length 18
# Episode 2401 total samples 52603 train steps 20
# Length 24
# Episode 2462 total samples 53872 train steps 30
# Length 20
# Episode 2513 total samples 55127 train steps 40
# Length 14
# Episode 2566 total samples 56411 train steps 50
# Length 34
# Episode 2627 total samples 57673 train steps 60
# Length 13
# Episode 2682 total samples 58951 train steps 70
# Length 38
# Episode 2737 total samples 60215 train steps 80
# Length 17
# Episode 2792 total samples 61504 train steps 90
# Length 40
# exploration  0.943681600002
# Episode 2843 total samples 62761 train steps 100
# Length 21
# Episode 2891 total samples 64022 train steps 110
# Length 17
# Episode 2943 total samples 65283 train steps 120
# Length 52
# Episode 2996 total samples 66544 train steps 129
# Length 45
# Episode 3052 total samples 67799 train steps 139
# Length 24
# Episode 3104 total samples 69100 train steps 149
# Length 72
# Episode 3153 total samples 70354 train steps 159
# Length 28
# Episode 3211 total samples 71622 train steps 169
# Length 29
# Episode 3263 total samples 72897 train steps 179
# Length 73
# Episode 3323 total samples 74173 train steps 189
# Length 40
# exploration  0.932417200002
# Episode 3379 total samples 75427 train steps 199
# Length 22
# Episode 3429 total samples 76685 train steps 209
# Length 12
# Episode 3470 total samples 77953 train steps 219
# Length 28
# Episode 3518 total samples 79223 train steps 228
# Length 25
# Episode 3575 total samples 80511 train steps 238
# Length 45
# Episode 3630 total samples 81775 train steps 248
# Length 42
# Episode 3680 total samples 83047 train steps 258
# Length 42
# Episode 3734 total samples 84310 train steps 268
# Length 21
# Episode 3790 total samples 85586 train steps 278
# Length 39
# Episode 3846 total samples 86848 train steps 288
# Length 60
# exploration  0.921153700003
# Episode 3902 total samples 88159 train steps 298
# Length 78
# Episode 3953 total samples 89415 train steps 308
# Length 49
# Episode 4002 total samples 90667 train steps 318
# Length 64
# Episode 4060 total samples 91926 train steps 328
# Length 20
# Episode 4114 total samples 93198 train steps 338
# Length 29
# Episode 4176 total samples 94479 train steps 348
# Length 45
# Episode 4228 total samples 95763 train steps 358
# Length 38
# Episode 4287 total samples 97036 train steps 368
# Length 24
# Episode 4339 total samples 98296 train steps 377
# Length 25
# Episode 4391 total samples 99551 train steps 387
# Length 24
# exploration  0.909901900003
# Episode 4451 total samples 100810 train steps 397
# Length 15
# Episode 4499 total samples 102069 train steps 407
# Length 17
# Episode 4554 total samples 103336 train steps 417
# Length 24
# Episode 4602 total samples 104605 train steps 427
# Length 21
# Episode 4652 total samples 105886 train steps 437
# Length 69
# Episode 4702 total samples 107172 train steps 447
# Length 65
# Episode 4762 total samples 108427 train steps 457
# Length 29
# Episode 4812 total samples 109679 train steps 466
# Length 21
# Episode 4862 total samples 110933 train steps 476
# Length 19
# Episode 4907 total samples 112189 train steps 486
# Length 10
# exploration  0.898640200003
# Episode 4956 total samples 113441 train steps 496
# Length 16
# Episode 5010 total samples 114757 train steps 506
# Length 66
# Episode 5063 total samples 116015 train steps 516
# Length 62
# Episode 5118 total samples 117266 train steps 526
# Length 12
# Episode 5177 total samples 118534 train steps 536
# Length 22
# Episode 5223 total samples 119791 train steps 545
# Length 11
# Episode 5270 total samples 121092 train steps 556
# Length 51
# Episode 5322 total samples 122354 train steps 565
# Length 14
# Episode 5379 total samples 123625 train steps 575
# Length 33
# Episode 5429 total samples 124889 train steps 585
# Length 22
# exploration  0.887374000004
# Episode 5475 total samples 126163 train steps 595
# Length 35
# Episode 5526 total samples 127418 train steps 605
# Length 25
# Episode 5576 total samples 128679 train steps 615
# Length 13
# Episode 5631 total samples 129939 train steps 625
# Length 14
# Episode 5681 total samples 131192 train steps 634
# Length 28
# Episode 5730 total samples 132452 train steps 644
# Length 24
# Episode 5779 total samples 133708 train steps 654
# Length 16
# Episode 5827 total samples 134979 train steps 664
# Length 24
# Episode 5876 total samples 136246 train steps 674
# Length 56
# Episode 5928 total samples 137520 train steps 684
# Length 39
# exploration  0.876091600004
# Episode 5976 total samples 138782 train steps 694
# Length 42
# Episode 6025 total samples 140063 train steps 704
# Length 46
# Episode 6076 total samples 141339 train steps 714
# Length 38
# Episode 6133 total samples 142591 train steps 723
# Length 15
# Episode 6188 total samples 143851 train steps 733
# Length 34
# Episode 6242 total samples 145105 train steps 743
# Length 10
# Episode 6294 total samples 146364 train steps 753
# Length 23
# Episode 6342 total samples 147652 train steps 763
# Length 44
# Episode 6394 total samples 148906 train steps 773
# Length 26
# Episode 6444 total samples 150159 train steps 783
# Length 81
# exploration  0.864835300004
# Episode 6497 total samples 151414 train steps 792
# Length 17
# Episode 6546 total samples 152676 train steps 802
# Length 27
# Episode 6594 total samples 153940 train steps 812
# Length 16
# Episode 6644 total samples 155200 train steps 822
# Length 66
# Episode 6694 total samples 156468 train steps 832
# Length 63
# Episode 6746 total samples 157731 train steps 842
# Length 31
# Episode 6792 total samples 159004 train steps 852
# Length 44
# Episode 6838 total samples 160269 train steps 862
# Length 23
# Episode 6882 total samples 161526 train steps 871
# Length 10
# exploration  0.853578100005
# Episode 6932 total samples 162784 train steps 881
# Length 30
# Episode 6977 total samples 164051 train steps 891
# Length 19
# Episode 7025 total samples 165312 train steps 901
# Length 58
# Episode 7076 total samples 166576 train steps 911
# Length 22
# Episode 7124 total samples 167839 train steps 921
# Length 16
# Episode 7169 total samples 169098 train steps 931
# Length 13
# Episode 7222 total samples 170355 train steps 940
# Length 10
# Episode 7279 total samples 171625 train steps 950
# Length 24
# Episode 7329 total samples 172879 train steps 960
# Length 13
# Episode 7376 total samples 174141 train steps 970
# Length 27
# exploration  0.842296600005
# Episode 7422 total samples 175400 train steps 980
# Length 24
# Episode 7463 total samples 176662 train steps 990
# Length 26
# Episode 7509 total samples 177914 train steps 999
# Length 51
# Episode 7559 total samples 179185 train steps 1009
# Length 56
# Episode 7607 total samples 180441 train steps 1019
# Length 21
# Episode 7654 total samples 181703 train steps 1029
# Length 25
# Episode 7711 total samples 182958 train steps 1039
# Length 20
# Episode 7756 total samples 184218 train steps 1049
# Length 20
# Episode 7805 total samples 185481 train steps 1059
# Length 25
# Episode 7853 total samples 186748 train steps 1068
# Length 30
# exploration  0.831022300006
# Episode 7906 total samples 188031 train steps 1078
# Length 46
# Episode 7957 total samples 189313 train steps 1089
# Length 42
# Episode 8003 total samples 190566 train steps 1098
# Length 24
# Episode 8049 total samples 191848 train steps 1108
# Length 36
# Episode 8099 total samples 193100 train steps 1118
# Length 21
# Episode 8148 total samples 194368 train steps 1128
# Length 18
# Episode 8202 total samples 195655 train steps 1138
# Length 45
# Episode 8252 total samples 196967 train steps 1148
# Length 70
# Episode 8305 total samples 198221 train steps 1158
# Length 25
# Episode 8354 total samples 199486 train steps 1168
# Length 30
# exploration  0.819752500006
# Episode 8398 total samples 200752 train steps 1178
# Length 30
# Episode 8447 total samples 202011 train steps 1188
# Length 44
# Episode 8489 total samples 203272 train steps 1198
# Length 39
# Episode 8530 total samples 204532 train steps 1207
# Length 46
# Episode 8575 total samples 205787 train steps 1217
# Length 55
# Episode 8620 total samples 207061 train steps 1227
# Length 26
# Episode 8667 total samples 208355 train steps 1237
# Length 54
# Episode 8718 total samples 209606 train steps 1247
# Length 23
# Episode 8774 total samples 210895 train steps 1257
# Length 67
# Episode 8820 total samples 212201 train steps 1267
# Length 56
# exploration  0.808472800006
# Episode 8861 total samples 213458 train steps 1277
# Length 36
# Episode 8903 total samples 214752 train steps 1287
# Length 53
# Episode 8949 total samples 216009 train steps 1297
# Length 16
# Episode 8996 total samples 217323 train steps 1307
# Length 76
# Episode 9041 total samples 218603 train steps 1317
# Length 36
# Episode 9094 total samples 219875 train steps 1327
# Length 45
# Episode 9151 total samples 221127 train steps 1337
# Length 22
# Episode 9199 total samples 222391 train steps 1347
# Length 19
# Episode 9242 total samples 223661 train steps 1357
# Length 26
# Episode 9298 total samples 224914 train steps 1367
# Length 13
# exploration  0.797194900007
# Episode 9347 total samples 226178 train steps 1377
# Length 16
# Episode 9388 total samples 227440 train steps 1386
# Length 45
# Episode 9433 total samples 228704 train steps 1396
# Length 23
# Episode 9481 total samples 229964 train steps 1406
# Length 21
# Episode 9529 total samples 231215 train steps 1416
# Length 25
# Episode 9579 total samples 232492 train steps 1426
# Length 29
# Episode 9626 total samples 233753 train steps 1436
# Length 24
# Episode 9670 total samples 235016 train steps 1446
# Length 19
# Episode 9721 total samples 236299 train steps 1456
# Length 45
# Episode 9770 total samples 237552 train steps 1465
# Length 28
# exploration  0.785936800007
# Episode 9817 total samples 238808 train steps 1475
# Length 14
# Episode 9863 total samples 240069 train steps 1485
# Length 27
# Episode 9912 total samples 241330 train steps 1495
# Length 28
# Episode 9962 total samples 242606 train steps 1505
# Length 48
# Episode 10011 total samples 243886 train steps 1515
# Length 32
# Episode 10057 total samples 245145 train steps 1525
# Length 34
# Episode 10103 total samples 246407 train steps 1535
# Length 23
# Episode 10148 total samples 247663 train steps 1544
# Length 25
# Episode 10202 total samples 248934 train steps 1554
# Length 27
# Episode 10249 total samples 250204 train steps 1564
# Length 22
# exploration  0.774646300007
# Episode 10289 total samples 251473 train steps 1574
# Length 53
# Episode 10333 total samples 252760 train steps 1584
# Length 54
# Episode 10383 total samples 254023 train steps 1594
# Length 27
# Episode 10437 total samples 255277 train steps 1604
# Length 10
# Episode 10485 total samples 256530 train steps 1614
# Length 33
# Episode 10527 total samples 257810 train steps 1624
# Length 67
# Episode 10578 total samples 259081 train steps 1634
# Length 21
# Episode 10629 total samples 260346 train steps 1643
# Length 16
# Episode 10674 total samples 261621 train steps 1653
# Length 51
# Episode 10718 total samples 262900 train steps 1663
# Length 36
# exploration  0.763390000008
# Episode 10764 total samples 264178 train steps 1673
# Length 43
# Episode 10817 total samples 265439 train steps 1683
# Length 57
# Episode 10859 total samples 266701 train steps 1693
# Length 19
# Episode 10902 total samples 267977 train steps 1703
# Length 28
# Episode 10953 total samples 269273 train steps 1713
# Length 86
# Episode 11004 total samples 270547 train steps 1723
# Length 67
# Episode 11050 total samples 271823 train steps 1733
# Length 43
# Episode 11100 total samples 273082 train steps 1743
# Length 35
# Episode 11146 total samples 274337 train steps 1753
# Length 21
# exploration  0.752114800008
# Episode 11200 total samples 275591 train steps 1763
# Length 11
# Episode 11254 total samples 276857 train steps 1772
# Length 21
# Episode 11296 total samples 278128 train steps 1782
# Length 49
# Episode 11348 total samples 279392 train steps 1792
# Length 40
# Episode 11396 total samples 280643 train steps 1802
# Length 21
# Episode 11439 total samples 281919 train steps 1812
# Length 30
# Episode 11484 total samples 283197 train steps 1822
# Length 41
# Episode 11537 total samples 284448 train steps 1832
# Length 31
# Episode 11590 total samples 285714 train steps 1842
# Length 37
# Episode 11632 total samples 286973 train steps 1851
# Length 20
# exploration  0.740862100009
# Episode 11681 total samples 288240 train steps 1861
# Length 49
# Episode 11728 total samples 289527 train steps 1871
# Length 56
# Episode 11775 total samples 290801 train steps 1881
# Length 60
# Episode 11826 total samples 292052 train steps 1891
# Length 12
# Episode 11875 total samples 293315 train steps 1901
# Length 13
# Episode 11913 total samples 294572 train steps 1911
# Length 17
# Episode 11960 total samples 295836 train steps 1921
# Length 19
# Episode 12006 total samples 297105 train steps 1931
# Length 60
# [2016-07-19 17:01:32,752] Observation '[-2.42863368 -3.92961385  0.13895418  2.20428338]' is not contained within observation space 'Box(4,)'.
# Episode 12049 total samples 298378 train steps 1941
# Length 25
# Episode 12105 total samples 299629 train steps 1950
# Length 13
# exploration  0.729595000009
# Episode 12152 total samples 300883 train steps 1960
# Length 25
# Episode 12197 total samples 302143 train steps 1970
# Length 35
# Episode 12238 total samples 303423 train steps 1980
# Length 31
# Episode 12289 total samples 304717 train steps 1990
# Length 62
# Episode 12336 total samples 305982 train steps 2000
# Length 22
# Episode 12386 total samples 307234 train steps 2010
# Length 31
# Episode 12443 total samples 308514 train steps 2020
# Length 41
# Episode 12489 total samples 309799 train steps 2030
# Length 57
# Episode 12538 total samples 311067 train steps 2040
# Length 27
# Episode 12584 total samples 312382 train steps 2050
# Length 73
# exploration  0.718344100009
# Episode 12633 total samples 313645 train steps 2060
# Length 13
# Episode 12679 total samples 314922 train steps 2070
# Length 27
# Episode 12721 total samples 316178 train steps 2080
# Length 13
# Episode 12772 total samples 317486 train steps 2090
# Length 64
# Episode 12825 total samples 318756 train steps 2100
# Length 20
# Episode 12876 total samples 320053 train steps 2110
# Length 48
# Episode 12922 total samples 321305 train steps 2120
# Length 11
# Episode 12961 total samples 322585 train steps 2130
# Length 64
# Episode 13012 total samples 323839 train steps 2139
# Length 11
# Episode 13055 total samples 325108 train steps 2149
# Length 50
# exploration  0.70705630001
# Episode 13109 total samples 326364 train steps 2159
# Length 15
# Episode 13161 total samples 327675 train steps 2169
# Length 90
# Episode 13211 total samples 328929 train steps 2179
# Length 40
# Episode 13254 total samples 330192 train steps 2189
# Length 22
# Episode 13300 total samples 331446 train steps 2199
# Length 31
# Episode 13347 total samples 332697 train steps 2209
# Length 33
# Episode 13398 total samples 333960 train steps 2219
# Length 21
# Episode 13442 total samples 335231 train steps 2228
# Length 38
# Episode 13495 total samples 336518 train steps 2239
# Length 42
# Episode 13538 total samples 337794 train steps 2249
# Length 35
# exploration  0.69578020001
# Episode 13592 total samples 339061 train steps 2258
# Length 42
# Episode 13634 total samples 340318 train steps 2268
# Length 15
# Episode 13683 total samples 341571 train steps 2278
# Length 17
# Episode 13727 total samples 342845 train steps 2288
# Length 73
# Episode 13772 total samples 344100 train steps 2298
# Length 17
# Episode 13826 total samples 345356 train steps 2308
# Length 19
# Episode 13867 total samples 346617 train steps 2317
# Length 47
# Episode 13913 total samples 347886 train steps 2327
# Length 25
# Episode 13956 total samples 349154 train steps 2337
# Length 28
# Episode 13997 total samples 350405 train steps 2347
# Length 18
# exploration  0.68450770001
# Episode 14043 total samples 351693 train steps 2357
# Length 44
# Episode 14091 total samples 352998 train steps 2367
# Length 75
# Episode 14140 total samples 354270 train steps 2377
# Length 42
# Episode 14193 total samples 355542 train steps 2387
# Length 47
# Episode 14240 total samples 356801 train steps 2397
# Length 58
# Episode 14280 total samples 358068 train steps 2407
# Length 44
# Episode 14322 total samples 359336 train steps 2417
# Length 18
# Episode 14373 total samples 360594 train steps 2427
# Length 14
# Episode 14416 total samples 361857 train steps 2437
# Length 52
# exploration  0.673254100011
# Episode 14462 total samples 363108 train steps 2446
# Length 13
# Episode 14504 total samples 364380 train steps 2456
# Length 42
# Episode 14551 total samples 365662 train steps 2466
# Length 40
# Episode 14603 total samples 366930 train steps 2476
# Length 34
# Episode 14651 total samples 368211 train steps 2486
# Length 48
# Episode 14693 total samples 369486 train steps 2496
# Length 56
# Episode 14739 total samples 370759 train steps 2506
# Length 27
# Episode 14783 total samples 372017 train steps 2516
# Length 32
# Episode 14829 total samples 373287 train steps 2526
# Length 26
# Episode 14874 total samples 374540 train steps 2536
# Length 24
# exploration  0.661997800011
# Episode 14914 total samples 375793 train steps 2545
# Length 104
# Episode 14957 total samples 377055 train steps 2555
# Length 43
# Episode 15004 total samples 378307 train steps 2565
# Length 23
# Episode 15051 total samples 379574 train steps 2575
# Length 66
# Episode 15092 total samples 380895 train steps 2585
# Length 110
# Episode 15136 total samples 382159 train steps 2595
# Length 39
# Episode 15186 total samples 383419 train steps 2605
# Length 22
# Episode 15224 total samples 384689 train steps 2615
# Length 23
# Episode 15274 total samples 385997 train steps 2625
# Length 66
# Episode 15336 total samples 387256 train steps 2635
# Length 13
# exploration  0.650733400011
# Episode 15385 total samples 388522 train steps 2645
# Length 18
# Episode 15433 total samples 389852 train steps 2655
# Length 80
# Episode 15485 total samples 391144 train steps 2665
# Length 44
# Episode 15526 total samples 392433 train steps 2675
# Length 54
# Episode 15579 total samples 393695 train steps 2685
# Length 20
# Episode 15623 total samples 394972 train steps 2695
# Length 54
# Episode 15664 total samples 396242 train steps 2705
# Length 58
# Episode 15712 total samples 397516 train steps 2715
# Length 60
# Episode 15747 total samples 398773 train steps 2725
# Length 41
# Episode 15787 total samples 400050 train steps 2735
# Length 72
# exploration  0.639474400012
# Episode 15839 total samples 401335 train steps 2745
# Length 46
# Episode 15883 total samples 402603 train steps 2755
# Length 35
# Episode 15928 total samples 403864 train steps 2765
# Length 15
# Episode 15967 total samples 405190 train steps 2775
# Length 81
# Episode 16007 total samples 406449 train steps 2785
# Length 24
# Episode 16050 total samples 407713 train steps 2795
# Length 39
# Episode 16094 total samples 409032 train steps 2805
# Length 86
# Episode 16137 total samples 410284 train steps 2815
# Length 21
# Episode 16193 total samples 411541 train steps 2825
# Length 27
# Episode 16242 total samples 412810 train steps 2835
# Length 53
# exploration  0.628175800012
# Episode 16284 total samples 414070 train steps 2844
# Length 21
# Episode 16332 total samples 415338 train steps 2854
# Length 20
# Episode 16373 total samples 416595 train steps 2864
# Length 18
# Episode 16419 total samples 417858 train steps 2874
# Length 41
# Episode 16465 total samples 419136 train steps 2884
# Length 47
# Episode 16511 total samples 420388 train steps 2894
# Length 24
# Episode 16548 total samples 421652 train steps 2904
# Length 48
# Episode 16593 total samples 422912 train steps 2913
# Length 52
# Episode 16632 total samples 424171 train steps 2923
# Length 10
# Episode 16684 total samples 425447 train steps 2933
# Length 27
# exploration  0.616921300013
# Episode 16736 total samples 426735 train steps 2943
# Length 86
# Episode 16780 total samples 428002 train steps 2953
# Length 29
# Episode 16826 total samples 429274 train steps 2963
# Length 33
# Episode 16868 total samples 430533 train steps 2973
# Length 18
# Episode 16909 total samples 431794 train steps 2983
# Length 90
# Episode 16955 total samples 433082 train steps 2993
# Length 54
# Episode 17000 total samples 434335 train steps 3003
# Length 12
# Episode 17046 total samples 435587 train steps 3013
# Length 16
# Episode 17090 total samples 436848 train steps 3022
# Length 28
# Episode 17131 total samples 438123 train steps 3032
# Length 34
# exploration  0.605666800013
# Episode 17175 total samples 439385 train steps 3042
# Length 12
# Episode 17218 total samples 440654 train steps 3052
# Length 44
# Episode 17270 total samples 441908 train steps 3062
# Length 25
# Episode 17310 total samples 443183 train steps 3072
# Length 51
# Episode 17353 total samples 444436 train steps 3082
# Length 36
# Episode 17390 total samples 445690 train steps 3091
# Length 12
# Episode 17434 total samples 446950 train steps 3101
# Length 30
# Episode 17484 total samples 448211 train steps 3111
# Length 22
# Episode 17533 total samples 449486 train steps 3121
# Length 33
# exploration  0.594415900013
# Episode 17577 total samples 450745 train steps 3131
# Length 21
# Episode 17624 total samples 452010 train steps 3141
# Length 18
# Episode 17669 total samples 453311 train steps 3151
# Length 78
# Episode 17710 total samples 454586 train steps 3161
# Length 29
# Episode 17754 total samples 455852 train steps 3171
# Length 35
# Episode 17794 total samples 457140 train steps 3181
# Length 53
# Episode 17845 total samples 458412 train steps 3191
# Length 24
# Episode 17894 total samples 459707 train steps 3201
# Length 47
# Episode 17942 total samples 460969 train steps 3211
# Length 18
# Episode 17981 total samples 462234 train steps 3221
# Length 30
# exploration  0.583151500014
# Episode 18010 total samples 463497 train steps 3231
# Length 30
# Episode 18055 total samples 464760 train steps 3240
# Length 16
# Episode 18104 total samples 466019 train steps 3250
# Length 41
# Episode 18147 total samples 467273 train steps 3260
# Length 28
# Episode 18197 total samples 468545 train steps 3270
# Length 31
# Episode 18240 total samples 469799 train steps 3280
# Length 12
# Episode 18285 total samples 471056 train steps 3290
# Length 68
# Episode 18333 total samples 472310 train steps 3299
# Length 28
# Episode 18380 total samples 473565 train steps 3309
# Length 12
# Episode 18433 total samples 474820 train steps 3319
# Length 16
# exploration  0.571897900014
# Episode 18487 total samples 476086 train steps 3329
# Length 33
# Episode 18533 total samples 477356 train steps 3339
# Length 41
# Episode 18575 total samples 478609 train steps 3349
# Length 58
# Episode 18613 total samples 479912 train steps 3359
# Length 63
# Episode 18657 total samples 481191 train steps 3369
# Length 58
# Episode 18696 total samples 482451 train steps 3379
# Length 46
# Episode 18743 total samples 483738 train steps 3389
# Length 55
# Episode 18784 total samples 485016 train steps 3399
# Length 40
# Episode 18826 total samples 486275 train steps 3409
# Length 16
# Episode 18875 total samples 487527 train steps 3418
# Length 58
# exploration  0.560621800014
# Episode 18924 total samples 488780 train steps 3428
# Length 22
# Episode 18979 total samples 490032 train steps 3438
# Length 18
# Episode 19029 total samples 491288 train steps 3448
# Length 58
# Episode 19071 total samples 492551 train steps 3458
# Length 20
# Episode 19109 total samples 493859 train steps 3468
# Length 69
# Episode 19158 total samples 495113 train steps 3478
# Length 18
# Episode 19204 total samples 496409 train steps 3488
# Length 52
# Episode 19262 total samples 497692 train steps 3498
# Length 35
# Episode 19318 total samples 498951 train steps 3508
# Length 32
# Episode 19361 total samples 500212 train steps 3517
# Length 12
# exploration  0.549352000015
# Episode 19406 total samples 501467 train steps 3527
# Length 29
# Episode 19454 total samples 502739 train steps 3537
# Length 55
# Episode 19497 total samples 503991 train steps 3547
# Length 18
# Episode 19539 total samples 505251 train steps 3557
# Length 10
# Episode 19583 total samples 506508 train steps 3567
# Length 33
# Episode 19623 total samples 507768 train steps 3576
# Length 11
# Episode 19668 total samples 509025 train steps 3586
# Length 14
# Episode 19712 total samples 510303 train steps 3596
# Length 36
# Episode 19759 total samples 511571 train steps 3606
# Length 28
# Episode 19802 total samples 512833 train steps 3616
# Length 15
# exploration  0.538092100015
# Episode 19844 total samples 514091 train steps 3626
# Length 17
# Episode 19896 total samples 515372 train steps 3636
# Length 62
# Episode 19940 total samples 516627 train steps 3646
# Length 16
# Episode 19986 total samples 517886 train steps 3655
# Length 28
# Episode 20029 total samples 519142 train steps 3665
# Length 10
# Episode 20074 total samples 520394 train steps 3675
# Length 19
# Episode 20119 total samples 521652 train steps 3685
# Length 53
# Episode 20162 total samples 522907 train steps 3695
# Length 21
# Episode 20214 total samples 524214 train steps 3705
# Length 67
# Episode 20262 total samples 525466 train steps 3715
# Length 28
# exploration  0.526812400016
# Episode 20307 total samples 526741 train steps 3725
# Length 32
# Episode 20352 total samples 528013 train steps 3735
# Length 31
# Episode 20400 total samples 529290 train steps 3745
# Length 64
# Episode 20439 total samples 530550 train steps 3754
# Length 15
# Episode 20485 total samples 531804 train steps 3764
# Length 31
# Episode 20532 total samples 533063 train steps 3774
# Length 32
# Episode 20575 total samples 534326 train steps 3784
# Length 26
# Episode 20629 total samples 535595 train steps 3794
# Length 24
# Episode 20673 total samples 536862 train steps 3804
# Length 29
# Episode 20720 total samples 538116 train steps 3814
# Length 16
# exploration  0.515532700016
# Episode 20765 total samples 539378 train steps 3823
# Length 27
# Episode 20810 total samples 540641 train steps 3833
# Length 52
# Episode 20854 total samples 541896 train steps 3843
# Length 15
# Episode 20894 total samples 543151 train steps 3853
# Length 33
# Episode 20952 total samples 544416 train steps 3863
# Length 45
# Episode 20994 total samples 545698 train steps 3873
# Length 70
# Episode 21039 total samples 546961 train steps 3883
# Length 22
# Episode 21080 total samples 548222 train steps 3892
# Length 20
# Episode 21137 total samples 549497 train steps 3902
# Length 41
# Episode 21183 total samples 550761 train steps 3912
# Length 31
# exploration  0.504276400016
# Episode 21226 total samples 552035 train steps 3922
# Length 85
# Episode 21275 total samples 553292 train steps 3932
# Length 11
# Episode 21329 total samples 554554 train steps 3942
# Length 12
# Episode 21380 total samples 555814 train steps 3952
# Length 13
# Episode 21432 total samples 557080 train steps 3962
# Length 40
# Episode 21473 total samples 558364 train steps 3972
# Length 57
# Episode 21522 total samples 559634 train steps 3982
# Length 38
# Episode 21566 total samples 560886 train steps 3991
# Length 25
# Episode 21615 total samples 562137 train steps 4001
# Length 35
# exploration  0.493016500016
# Episode 21656 total samples 563411 train steps 4011
# Length 46
# Episode 21709 total samples 564680 train steps 4021
# Length 22
# Episode 21757 total samples 565938 train steps 4031
# Length 18
# Episode 21804 total samples 567197 train steps 4041
# Length 10
# Episode 21851 total samples 568460 train steps 4051
# Length 66
# Episode 21896 total samples 569722 train steps 4060
# Length 17
# Episode 21949 total samples 571012 train steps 4071
# Length 53
# Episode 21991 total samples 572266 train steps 4080
# Length 32
# Episode 22044 total samples 573531 train steps 4090
# Length 22
# Episode 22086 total samples 574782 train steps 4100
# Length 39
# exploration  0.481758400016
# Episode 22137 total samples 576060 train steps 4110
# Length 39
# Episode 22187 total samples 577328 train steps 4120
# Length 28
# Episode 22234 total samples 578613 train steps 4130
# Length 62
# Episode 22279 total samples 579873 train steps 4140
# Length 30
# Episode 22316 total samples 581143 train steps 4150
# Length 92
# Episode 22358 total samples 582395 train steps 4159
# Length 39
# Episode 22412 total samples 583661 train steps 4169
# Length 40
# Episode 22462 total samples 584959 train steps 4179
# Length 79
# Episode 22507 total samples 586210 train steps 4189
# Length 28
# Episode 22560 total samples 587473 train steps 4199
# Length 31
# exploration  0.470489500016
# Episode 22605 total samples 588732 train steps 4209
# Length 13
# Episode 22650 total samples 589991 train steps 4219
# Length 35
# Episode 22697 total samples 591281 train steps 4229
# Length 51
# Episode 22739 total samples 592595 train steps 4239
# Length 77
# Episode 22790 total samples 593850 train steps 4249
# Length 15
# Episode 22837 total samples 595110 train steps 4259
# Length 28
# Episode 22890 total samples 596406 train steps 4269
# Length 65
# Episode 22940 total samples 597672 train steps 4279
# Length 16
# Episode 22987 total samples 598935 train steps 4289
# Length 37
# Episode 23038 total samples 600221 train steps 4299
# Length 52
# exploration  0.459223300015
# Episode 23097 total samples 601508 train steps 4309
# Length 58
# Episode 23138 total samples 602783 train steps 4319
# Length 47
# Episode 23181 total samples 604036 train steps 4329
# Length 29
# Episode 23227 total samples 605296 train steps 4338
# Length 14
# Episode 23274 total samples 606598 train steps 4349
# Length 92
# Episode 23330 total samples 607852 train steps 4358
# Length 30
# Episode 23377 total samples 609111 train steps 4368
# Length 22
# Episode 23425 total samples 610372 train steps 4378
# Length 14
# Episode 23463 total samples 611630 train steps 4388
# Length 21
# Episode 23514 total samples 612884 train steps 4398
# Length 34
# exploration  0.447969700015
# Episode 23560 total samples 614141 train steps 4407
# Length 98
# Episode 23614 total samples 615399 train steps 4417
# Length 22
# Episode 23671 total samples 616666 train steps 4427
# Length 25
# Episode 23723 total samples 617932 train steps 4437
# Length 33
# Episode 23767 total samples 619187 train steps 4447
# Length 18
# Episode 23816 total samples 620451 train steps 4457
# Length 51
# Episode 23865 total samples 621728 train steps 4467
# Length 45
# Episode 23914 total samples 622979 train steps 4477
# Length 44
# Episode 23957 total samples 624262 train steps 4487
# Length 50
# Episode 24006 total samples 625515 train steps 4496
# Length 28
# exploration  0.436717900015
# Episode 24060 total samples 626780 train steps 4506
# Length 44
# Episode 24108 total samples 628053 train steps 4516
# Length 29
# Episode 24151 total samples 629306 train steps 4526
# Length 29
# Episode 24195 total samples 630574 train steps 4536
# Length 19
# Episode 24251 total samples 631837 train steps 4546
# Length 17
# Episode 24306 total samples 633124 train steps 4556
# Length 50
# Episode 24361 total samples 634422 train steps 4566
# Length 48
# Episode 24414 total samples 635683 train steps 4576
# Length 17
# Episode 24472 total samples 636949 train steps 4586
# Length 26
# Episode 24524 total samples 638225 train steps 4596
# Length 47
# exploration  0.425437300014
# Episode 24568 total samples 639478 train steps 4605
# Length 13
# Episode 24610 total samples 640733 train steps 4615
# Length 20
# Episode 24653 total samples 641990 train steps 4625
# Length 17
# Episode 24705 total samples 643284 train steps 4635
# Length 59
# Episode 24775 total samples 644642 train steps 4646
# Length 118
# Episode 24827 total samples 645925 train steps 4656
# Length 39
# Episode 24867 total samples 647188 train steps 4666
# Length 32
# Episode 24910 total samples 648439 train steps 4675
# Length 13
# Episode 24957 total samples 649690 train steps 4685
# Length 36
# exploration  0.414161200014
# Episode 25007 total samples 650945 train steps 4695
# Length 13
# Episode 25057 total samples 652204 train steps 4705
# Length 13
# Episode 25103 total samples 653502 train steps 4715
# Length 76
# Episode 25149 total samples 654783 train steps 4725
# Length 42
# Episode 25201 total samples 656050 train steps 4735
# Length 54
# Episode 25251 total samples 657306 train steps 4745
# Length 21
# Episode 25295 total samples 658584 train steps 4755
# Length 61
# Episode 25342 total samples 659847 train steps 4765
# Length 32
# Episode 25391 total samples 661155 train steps 4775
# Length 74
# Episode 25440 total samples 662411 train steps 4785
# Length 17
# exploration  0.402897700014
# Episode 25488 total samples 663674 train steps 4794
# Length 18
# Episode 25546 total samples 664940 train steps 4804
# Length 43
# Episode 25589 total samples 666206 train steps 4814
# Length 29
# Episode 25632 total samples 667512 train steps 4824
# Length 58
# Episode 25674 total samples 668810 train steps 4835
# Length 49
# Episode 25724 total samples 670080 train steps 4844
# Length 24
# Episode 25774 total samples 671362 train steps 4855
# Length 32
# Episode 25815 total samples 672623 train steps 4864
# Length 15
# Episode 25867 total samples 673889 train steps 4874
# Length 27
# Episode 25918 total samples 675155 train steps 4884
# Length 38
# exploration  0.391626100013
# Episode 25958 total samples 676414 train steps 4894
# Length 58
# Episode 26005 total samples 677673 train steps 4904
# Length 40
# Episode 26047 total samples 678966 train steps 4914
# Length 94
# Episode 26098 total samples 680225 train steps 4924
# Length 44
# Episode 26143 total samples 681516 train steps 4934
# Length 50
# Episode 26197 total samples 682769 train steps 4944
# Length 13
# Episode 26255 total samples 684031 train steps 4953
# Length 35
